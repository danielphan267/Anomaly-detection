# %% [markdown]
# ## Import Libraries and config files

# %%
# !pip install scipy

# %%
import cv2
import scipy.io
import os
import gc
import sklearn.preprocessing
import matplotlib
import tensorflow
import keras.optimizers
import warnings
import scipy.io as sio
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
# import tensorflow_hub as hub
from sklearn.metrics import roc_curve, auc, confusion_matrix
from skimage.transform import resize
import numpy as np
import networkx as nx
import pandas as pd
from matplotlib.animation import FuncAnimation, PillowWriter 
from keras import backend as K
from keras.models import Sequential
from keras.regularizers import l2
from keras.models import Model
from keras.layers.core import Dense, Dropout, Flatten
from keras.layers.convolutional import Conv3D, MaxPooling3D, ZeroPadding3D, AveragePooling3D 
from tensorflow.keras.layers import BatchNormalization, Activation, Input
from tensorflow.keras import layers
#from scipy.misc import imresize
from keras.models import model_from_json
from datetime import datetime
from keras.utils.data_utils import get_file
from keras.utils.layer_utils import get_source_inputs
from keras.utils import layer_utils
import matplotlib.pyplot as plt
matplotlib.use('Agg')
# %matplotlib inline
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

from keras import layers
from keras.layers import Activation
from keras.layers import Dense
from keras.layers import Input
from keras.layers import BatchNormalization
from keras.layers import Conv3D
from keras.layers import MaxPooling3D
from keras.layers import AveragePooling3D
from keras.layers import Dropout
from keras.layers import Reshape
from keras.layers import Lambda
from keras.layers import GlobalAveragePooling3D

# %%
C3D_MEAN_PATH = 'https://github.com/adamcasson/c3d/releases/download/v0.1/c3d_mean.npy'

# %%
# path to pretrained models with no top (no classification layer)
WEIGHTS_PATH_NO_TOP = {
    'rgb_kinetics_only' : 'https://github.com/dlpbc/keras-kinetics-i3d/releases/download/v0.2/rgb_inception_i3d_kinetics_only_tf_dim_ordering_tf_kernels_no_top.h5',
    'flow_kinetics_only' : 'https://github.com/dlpbc/keras-kinetics-i3d/releases/download/v0.2/flow_inception_i3d_kinetics_only_tf_dim_ordering_tf_kernels_no_top.h5',
    'rgb_imagenet_and_kinetics' : 'https://github.com/dlpbc/keras-kinetics-i3d/releases/download/v0.2/rgb_inception_i3d_imagenet_and_kinetics_tf_dim_ordering_tf_kernels_no_top.h5',
    'flow_imagenet_and_kinetics' : 'https://github.com/dlpbc/keras-kinetics-i3d/releases/download/v0.2/flow_inception_i3d_imagenet_and_kinetics_tf_dim_ordering_tf_kernels_no_top.h5'
}

WEIGHTS_PATH = {
    'rgb_kinetics_only' : 'https://github.com/dlpbc/keras-kinetics-i3d/releases/download/v0.2/rgb_inception_i3d_kinetics_only_tf_dim_ordering_tf_kernels.h5',
    'flow_kinetics_only' : 'https://github.com/dlpbc/keras-kinetics-i3d/releases/download/v0.2/flow_inception_i3d_kinetics_only_tf_dim_ordering_tf_kernels.h5',
    'rgb_imagenet_and_kinetics' : 'https://github.com/dlpbc/keras-kinetics-i3d/releases/download/v0.2/rgb_inception_i3d_imagenet_and_kinetics_tf_dim_ordering_tf_kernels.h5',
    'flow_imagenet_and_kinetics' : 'https://github.com/dlpbc/keras-kinetics-i3d/releases/download/v0.2/flow_inception_i3d_imagenet_and_kinetics_tf_dim_ordering_tf_kernels.h5'
}

# %% [markdown]
# ## Parameters

# %%
c3d_model_weights = 'F:\DeCuong\Anomaly Detection/Anomaly Recognition/sports1M_weights_tf.h5'
abnormal_videos_path="F:\DeCuong\Anomaly Detection/Anomaly Recognition/Anomaly Videos"
normal_videos_path="F:\DeCuong\Anomaly Detection/Anomaly Recognition/Normal Videos/Training-Normal-Videos-Part-1"
raw_normal_train_features_c3d="F:\DeCuong\Anomaly Detection/Anomaly Recognition/Raw Normal videos features C3d"
raw_abnormal_train_features_c3d="F:\DeCuong\Anomaly Detection/Anomaly Recognition/Raw Anomaly videos features C3d"
processed_normal_train_features_c3d="F:\DeCuong\Anomaly Detection/Anomaly Recognition/Pre-processed Normal Video features C3d"
processed_abnormal_train_features_c3d="F:\DeCuong\Anomaly Detection/Anomaly Recognition/Pre-processed Anomaly video features C3d"
raw_normal_train_features_i3d="F:\DeCuong\Anomaly Detection/Anomaly Recognition/Raw Normal videos features i3d"
raw_abnormal_train_features_i3d="F:\DeCuong\Anomaly Detection/Anomaly Recognition/Raw Anomaly videos features i3d"
processed_normal_train_features_i3d="F:\DeCuong\Anomaly Detection/Anomaly Recognition/Pre-processed Normal Video features i3d"
processed_abnormal_train_features_i3d="F:\DeCuong\Anomaly Detection/Anomaly Recognition/Pre-processed Anomaly video features i3d"
output_dir = "F:\DeCuong\Anomaly Detection/Anomaly Recognition/Trained_models/"
output_folder_c3d = 'F:\DeCuong\Anomaly Detection/Anomaly Recognition/output_videos'
output_folder_i3d = 'F:\DeCuong\Anomaly Detection/Anomaly Recognition/output_videos_demo'

# %%
WEIGHTS_NAME = ['rgb_kinetics_only', 'flow_kinetics_only', 'rgb_imagenet_and_kinetics', 'flow_imagenet_and_kinetics']

frame_height = 240
frame_width = 320
channels = 3

c3d_frame_count = 16
i3d_frame_count = 16

features_per_bag = 32

# %% [markdown]
# ## Chunks work

# %%
def divide_chunks(l, n):
  """Apply divide_chunks to an array, getting chunks 
  of specified size
  """
  for i in range(0, len(l), n): 
    yield l[i:i + n]

# %% [markdown]
# ## Array Util

# %%
def sliding_window(arr, size, stride):
    """Apply sliding window to an array, getting chunks of
    of specified size using the specified stride
    :param arr: Array to be divided
    :param size: Size of the chunks
    :param stride: Number of frames to skip for the next chunk
    :returns: Tensor with the resulting chunks
    :rtype: np.ndarray
    """
    num_chunks = int((len(arr) - size) / stride) + 2
    result = []
    for i in range(0,  num_chunks * stride, stride):
        if len(arr[i:i + size]) > 0:
            result.append(arr[i:i + size])
    return np.array(result)


def interpolate(features, features_per_bag):
    """Transform a bag with an arbitrary number of features into a bag
    with a fixed amount, using interpolation of consecutive features
    :param features: Bag of features to pad
    :param features_per_bag: Number of features to obtain
    :returns: Interpolated features
    :rtype: np.ndarray
    """
    feature_size = np.array(features).shape[1]
    interpolated_features = np.zeros((features_per_bag, feature_size))
    interpolation_indices = np.round(np.linspace(0, len(features) - 1, num=features_per_bag + 1))
    count = 0
    for index in range(0, len(interpolation_indices)-1):
        start = int(interpolation_indices[index])
        end = int(interpolation_indices[index + 1])

        assert end >= start

        if start == end:
            temp_vect = features[start, :]
        else:
            temp_vect = np.mean(features[start:end+1, :], axis=0)

        temp_vect = temp_vect / np.linalg.norm(temp_vect)

        if np.linalg.norm(temp_vect) == 0:
            print("Error")

        interpolated_features[count,:]=temp_vect
        count = count + 1
    del interpolation_indices
    gc.collect(generation=2)
    return np.array(interpolated_features)


def extrapolate(outputs, num_frames):
    """Expand output to match the video length
    :param outputs: Array of predicted outputs
    :param num_frames: Expected size of the output array
    :returns: Array of output size
    :rtype: np.ndarray
    """

    extrapolated_outputs = []
    extrapolation_indices = np.round(np.linspace(0, len(outputs) - 1, num=num_frames))
    for index in extrapolation_indices:
        extrapolated_outputs.append(outputs[int(index)])
    del extrapolation_indices
    gc.collect(generation=2)
    return np.array(extrapolated_outputs)

# %% [markdown]
# ## Video Util

# %%
def get_video_clips(video_path, frame_count):
    """Divides the input video into non-overlapping clips
    :param video_path: Path to the video
    :returns: Array with the fragments of video
    :rtype: np.ndarray
    """
    frames = get_video_frames(video_path)
    clips = sliding_window(frames, frame_count, frame_count)
    return clips, len(frames)

# %%
def get_video_frames(video_path):
    """Reads the video given a file path
    :param video_path: Path to the video
    :returns: Video as an array of frames
    :rtype: np.ndarray
    """
    cap = cv2.VideoCapture(video_path)
    frames = []
    while (cap.isOpened()):
        ret, frame = cap.read()
        if ret == True:
            frames.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
            del frame
        else:
            break
    cap.release()
    del cap
    gc.collect(generation=2)
    return frames

# %% [markdown]
# ## Video pre-processing I3d

# %%
def preprocess_input_i3d(video):
    """Preprocess video input to make it suitable for feature extraction.
    The video is resized, cropped, resampled and training mean is substracted
    to make it suitable for the network
    :param video: Video to be processed
    :returns: Preprocessed video
    :rtype: np.ndarray
    """
    
    intervals = np.ceil(np.linspace(0, video.shape[0] - 1, 16)).astype(int)
    frames = video[intervals]

    # Reshape to 224x224
    reshape_frames = np.zeros((frames.shape[0], 224, 224, frames.shape[3]))
    for i, img in enumerate(frames):
        img = resize(img, (224, 224))
        reshape_frames[i, :, :, :] = img
        del img

    reshape_frames = np.expand_dims(reshape_frames, axis=0)
    del intervals
    del frames
    gc.collect(generation=2)
    return reshape_frames

# %% [markdown]
# ## Segment Utils

# %%
def transform_into_segments(features, n_segments=32):
  """This will convert the vector 
  into 32 segments of feature vectors"""
#   if features.shape[0] < n_segments:
#       raise RuntimeError()
  "Number of prev segments lesser than expected output size"
  

  cuts = np.linspace(0, features.shape[0], n_segments,
                       dtype=int, endpoint=False)

  new_feats = []
  for i, j in zip(cuts[:-1], cuts[1:]):
      new_feats.append(np.mean(features[i:j,:], axis=0))

  new_feats.append(np.mean(features[cuts[-1]:,:], axis=0))

  new_feats = np.array(new_feats)
  new_feats = sklearn.preprocessing.normalize(new_feats, axis=1)
  del cuts
  gc.collect(generation=2)
  return new_feats

# %% [markdown]
# # I3d

# %%
def _obtain_input_shape(input_shape,
                        default_frame_size,
                        min_frame_size,
                        default_num_frames,
                        min_num_frames,
                        data_format,
                        require_flatten,
                        weights=None):
    """Internal utility to compute/validate the model's input shape.
    (Adapted from `keras/applications/imagenet_utils.py`)
    # Arguments
        input_shape: either None (will return the default network input shape),
            or a user-provided shape to be validated.
        default_frame_size: default input frames(images) width/height for the model.
        min_frame_size: minimum input frames(images) width/height accepted by the model.
        default_num_frames: default input number of frames(images) for the model.
        min_num_frames: minimum input number of frames accepted by the model.
        data_format: image data format to use.
        require_flatten: whether the model is expected to
            be linked to a classifier via a Flatten layer.
        weights: one of `None` (random initialization)
            or 'kinetics_only' (pre-training on Kinetics dataset).
            or 'imagenet_and_kinetics' (pre-training on ImageNet and Kinetics datasets).
            If weights='kinetics_only' or weights=='imagenet_and_kinetics' then
            input channels must be equal to 3.
    # Returns
        An integer shape tuple (may include None entries).
    # Raises
        ValueError: in case of invalid argument values.
    """
    if weights != 'kinetics_only' and weights != 'imagenet_and_kinetics' and input_shape and len(input_shape) == 4:
        if data_format == 'channels_first':
            if input_shape[0] not in {1, 3}:
                warnings.warn(
                    'This model usually expects 1 or 3 input channels. '
                    'However, it was passed an input_shape with ' +
                    str(input_shape[0]) + ' input channels.')
            default_shape = (input_shape[0], default_num_frames, default_frame_size, default_frame_size)
        else:
            if input_shape[-1] not in {1, 3}:
                warnings.warn(
                    'This model usually expects 1 or 3 input channels. '
                    'However, it was passed an input_shape with ' +
                    str(input_shape[-1]) + ' input channels.')
            default_shape = (default_num_frames, default_frame_size, default_frame_size, input_shape[-1])
    else:
        if data_format == 'channels_first':
            default_shape = (3, default_num_frames, default_frame_size, default_frame_size)
        else:
            default_shape = (default_num_frames, default_frame_size, default_frame_size, 3)
    if (weights == 'kinetics_only' or weights == 'imagenet_and_kinetics') and require_flatten:
        if input_shape is not None:
            if input_shape != default_shape:
                raise ValueError('When setting`include_top=True` '
                                 'and loading `imagenet` weights, '
                                 '`input_shape` should be ' +
                                 str(default_shape) + '.')
        return default_shape

    if input_shape:
        if data_format == 'channels_first':
            if input_shape is not None:
                if len(input_shape) != 4:
                    raise ValueError(
                        '`input_shape` must be a tuple of four integers.')
                if input_shape[0] != 3 and (weights == 'kinetics_only' or weights == 'imagenet_and_kinetics'):
                    raise ValueError('The input must have 3 channels; got '
                                     '`input_shape=' + str(input_shape) + '`')

                if input_shape[1] is not None and input_shape[1] < min_num_frames:
                    raise ValueError('Input number of frames must be at least ' +
                                     str(min_num_frames) + '; got '
                                     '`input_shape=' + str(input_shape) + '`')

                if ((input_shape[2] is not None and input_shape[2] < min_frame_size) or
                   (input_shape[3] is not None and input_shape[3] < min_frame_size)):
                    raise ValueError('Input size must be at least ' +
                                     str(min_frame_size) + 'x' + str(min_frame_size) + '; got '
                                     '`input_shape=' + str(input_shape) + '`')
        else:
            if input_shape is not None:
                if len(input_shape) != 4:
                    raise ValueError(
                        '`input_shape` must be a tuple of four integers.')
                if input_shape[-1] != 3 and (weights == 'kinetics_only' or weights == 'imagenet_and_kinetics'):
                    raise ValueError('The input must have 3 channels; got '
                                     '`input_shape=' + str(input_shape) + '`')

                if input_shape[0] is not None and input_shape[0] < min_num_frames:
                    raise ValueError('Input number of frames must be at least ' +
                                     str(min_num_frames) + '; got '
                                     '`input_shape=' + str(input_shape) + '`')

                if ((input_shape[1] is not None and input_shape[1] < min_frame_size) or
                   (input_shape[2] is not None and input_shape[2] < min_frame_size)):
                    raise ValueError('Input size must be at least ' +
                                     str(min_frame_size) + 'x' + str(min_frame_size) + '; got '
                                     '`input_shape=' + str(input_shape) + '`')
    else:
        if require_flatten:
            input_shape = default_shape
        else:
            if data_format == 'channels_first':
                input_shape = (3, None, None, None)
            else:
                input_shape = (None, None, None, 3)
    if require_flatten:
        if None in input_shape:
            raise ValueError('If `include_top` is True, '
                             'you should specify a static `input_shape`. '
                             'Got `input_shape=' + str(input_shape) + '`')
    return input_shape

# %%
def conv3d_bn(x,
              filters,
              num_frames,
              num_row,
              num_col,
              padding='same',
              strides=(1, 1, 1),
              use_bias = False,
              use_activation_fn = True,
              use_bn = True,
              name=None):
    """Utility function to apply conv3d + BN.
    # Arguments
        x: input tensor.
        filters: filters in `Conv3D`.
        num_frames: frames (time depth) of the convolution kernel.
        num_row: height of the convolution kernel.
        num_col: width of the convolution kernel.
        padding: padding mode in `Conv3D`.
        strides: strides in `Conv3D`.
        use_bias: use bias or not  
        use_activation_fn: use an activation function or not.
        use_bn: use batch normalization or not.
        name: name of the ops; will become `name + '_conv'`
            for the convolution and `name + '_bn'` for the
            batch norm layer.
    # Returns
        Output tensor after applying `Conv3D` and `BatchNormalization`.
    """
    if name is not None:
        bn_name = name + '_bn'
        conv_name = name + '_conv'
    else:
        bn_name = None
        conv_name = None

    x = Conv3D(
        filters, (num_frames, num_row, num_col),
        strides=strides,
        padding=padding,
        use_bias=use_bias,
        name=conv_name)(x)

    if use_bn:
        if K.image_data_format() == 'channels_first':
            bn_axis = 1
        else:
            bn_axis = 4
        x = BatchNormalization(axis=bn_axis, scale=False, name=bn_name)(x)

    if use_activation_fn:
        x = Activation('relu', name=name)(x)

    return x

# %%
def Inception_Inflated3d(include_top=True,
                weights=None,
                input_tensor=None,
                input_shape=None,
                dropout_prob=0.0,
                endpoint_logit=True,
                classes=400):
    """Instantiates the Inflated 3D Inception v1 architecture.
    Optionally loads weights pre-trained
    on Kinetics. Note that when using TensorFlow,
    for best performance you should set
    `image_data_format='channels_last'` in your Keras config
    at ~/.keras/keras.json.
    The model and the weights are compatible with both
    TensorFlow and Theano. The data format
    convention used by the model is the one
    specified in your Keras config file.
    Note that the default input frame(image) size for this model is 224x224.
    # Arguments
        include_top: whether to include the the classification 
            layer at the top of the network.
        weights: one of `None` (random initialization)
            or 'kinetics_only' (pre-training on Kinetics dataset only).
            or 'imagenet_and_kinetics' (pre-training on ImageNet and Kinetics datasets).
        input_tensor: optional Keras tensor (i.e. output of `layers.Input()`)
            to use as image input for the model.
        input_shape: optional shape tuple, only to be specified
            if `include_top` is False (otherwise the input shape
            has to be `(NUM_FRAMES, 224, 224, 3)` (with `channels_last` data format)
            or `(NUM_FRAMES, 3, 224, 224)` (with `channels_first` data format).
            It should have exactly 3 inputs channels.
            NUM_FRAMES should be no smaller than 8. The authors used 64
            frames per example for training and testing on kinetics dataset
            Also, Width and height should be no smaller than 32.
            E.g. `(64, 150, 150, 3)` would be one valid value.
        dropout_prob: optional, dropout probability applied in dropout layer
            after global average pooling layer. 
            0.0 means no dropout is applied, 1.0 means dropout is applied to all features.
            Note: Since Dropout is applied just before the classification
            layer, it is only useful when `include_top` is set to True.
        endpoint_logit: (boolean) optional. If True, the model's forward pass
            will end at producing logits. Otherwise, softmax is applied after producing
            the logits to produce the class probabilities prediction. Setting this parameter 
            to True is particularly useful when you want to combine results of rgb model
            and optical flow model.
            - `True` end model forward pass at logit output
            - `False` go further after logit to produce softmax predictions
            Note: This parameter is only useful when `include_top` is set to True.
        classes: optional number of classes to classify images
            into, only to be specified if `include_top` is True, and
            if no `weights` argument is specified.
    # Returns
        A Keras model instance.
    # Raises
        ValueError: in case of invalid argument for `weights`,
            or invalid input shape.
    """
    if not (weights in WEIGHTS_NAME or weights is None or os.path.exists(weights)):
        raise ValueError('The `weights` argument should be either '
                         '`None` (random initialization) or %s' % 
                         str(WEIGHTS_NAME) + ' ' 
                         'or a valid path to a file containing `weights` values')

    if weights in WEIGHTS_NAME and include_top and classes != 400:
        raise ValueError('If using `weights` as one of these %s, with `include_top`'
                         ' as true, `classes` should be 400' % str(WEIGHTS_NAME))

    # Determine proper input shape
    input_shape = _obtain_input_shape(
        input_shape,
        default_frame_size=224, 
        min_frame_size=32, 
        default_num_frames=64,
        min_num_frames=8,
        data_format=K.image_data_format(),
        require_flatten=include_top,
        weights=weights)

    if input_tensor is None:
        img_input = Input(shape=input_shape)
    else:
        if not K.is_keras_tensor(input_tensor):
            img_input = Input(tensor=input_tensor, shape=input_shape)
        else:
            img_input = input_tensor

    if K.image_data_format() == 'channels_first':
        channel_axis = 1
    else:
        channel_axis = 4

    # Downsampling via convolution (spatial and temporal)
    x = conv3d_bn(img_input, 64, 7, 7, 7, strides=(2, 2, 2), padding='same', name='Conv3d_1a_7x7')

    # Downsampling (spatial only)
    x = MaxPooling3D((1, 3, 3), strides=(1, 2, 2), padding='same', name='MaxPool2d_2a_3x3')(x)
    x = conv3d_bn(x, 64, 1, 1, 1, strides=(1, 1, 1), padding='same', name='Conv3d_2b_1x1')
    x = conv3d_bn(x, 192, 3, 3, 3, strides=(1, 1, 1), padding='same', name='Conv3d_2c_3x3')

    # Downsampling (spatial only)
    x = MaxPooling3D((1, 3, 3), strides=(1, 2, 2), padding='same', name='MaxPool2d_3a_3x3')(x)

    # Mixed 3b
    branch_0 = conv3d_bn(x, 64, 1, 1, 1, padding='same', name='Conv3d_3b_0a_1x1')

    branch_1 = conv3d_bn(x, 96, 1, 1, 1, padding='same', name='Conv3d_3b_1a_1x1')
    branch_1 = conv3d_bn(branch_1, 128, 3, 3, 3, padding='same', name='Conv3d_3b_1b_3x3')

    branch_2 = conv3d_bn(x, 16, 1, 1, 1, padding='same', name='Conv3d_3b_2a_1x1')
    branch_2 = conv3d_bn(branch_2, 32, 3, 3, 3, padding='same', name='Conv3d_3b_2b_3x3')

    branch_3 = MaxPooling3D((3, 3, 3), strides=(1, 1, 1), padding='same', name='MaxPool2d_3b_3a_3x3')(x)
    branch_3 = conv3d_bn(branch_3, 32, 1, 1, 1, padding='same', name='Conv3d_3b_3b_1x1')

    x = layers.concatenate(
        [branch_0, branch_1, branch_2, branch_3],
        axis=channel_axis,
        name='Mixed_3b')

    # Mixed 3c
    branch_0 = conv3d_bn(x, 128, 1, 1, 1, padding='same', name='Conv3d_3c_0a_1x1')

    branch_1 = conv3d_bn(x, 128, 1, 1, 1, padding='same', name='Conv3d_3c_1a_1x1')
    branch_1 = conv3d_bn(branch_1, 192, 3, 3, 3, padding='same', name='Conv3d_3c_1b_3x3')

    branch_2 = conv3d_bn(x, 32, 1, 1, 1, padding='same', name='Conv3d_3c_2a_1x1')
    branch_2 = conv3d_bn(branch_2, 96, 3, 3, 3, padding='same', name='Conv3d_3c_2b_3x3')

    branch_3 = MaxPooling3D((3, 3, 3), strides=(1, 1, 1), padding='same', name='MaxPool2d_3c_3a_3x3')(x)
    branch_3 = conv3d_bn(branch_3, 64, 1, 1, 1, padding='same', name='Conv3d_3c_3b_1x1')

    x = layers.concatenate(
        [branch_0, branch_1, branch_2, branch_3],
        axis=channel_axis,
        name='Mixed_3c')


    # Downsampling (spatial and temporal)
    x = MaxPooling3D((3, 3, 3), strides=(2, 2, 2), padding='same', name='MaxPool2d_4a_3x3')(x)

    # Mixed 4b
    branch_0 = conv3d_bn(x, 192, 1, 1, 1, padding='same', name='Conv3d_4b_0a_1x1')

    branch_1 = conv3d_bn(x, 96, 1, 1, 1, padding='same', name='Conv3d_4b_1a_1x1')
    branch_1 = conv3d_bn(branch_1, 208, 3, 3, 3, padding='same', name='Conv3d_4b_1b_3x3')

    branch_2 = conv3d_bn(x, 16, 1, 1, 1, padding='same', name='Conv3d_4b_2a_1x1')
    branch_2 = conv3d_bn(branch_2, 48, 3, 3, 3, padding='same', name='Conv3d_4b_2b_3x3')

    branch_3 = MaxPooling3D((3, 3, 3), strides=(1, 1, 1), padding='same', name='MaxPool2d_4b_3a_3x3')(x)
    branch_3 = conv3d_bn(branch_3, 64, 1, 1, 1, padding='same', name='Conv3d_4b_3b_1x1')

    x = layers.concatenate(
        [branch_0, branch_1, branch_2, branch_3],
        axis=channel_axis,
        name='Mixed_4b')

    # Mixed 4c
    branch_0 = conv3d_bn(x, 160, 1, 1, 1, padding='same', name='Conv3d_4c_0a_1x1')

    branch_1 = conv3d_bn(x, 112, 1, 1, 1, padding='same', name='Conv3d_4c_1a_1x1')
    branch_1 = conv3d_bn(branch_1, 224, 3, 3, 3, padding='same', name='Conv3d_4c_1b_3x3')

    branch_2 = conv3d_bn(x, 24, 1, 1, 1, padding='same', name='Conv3d_4c_2a_1x1')
    branch_2 = conv3d_bn(branch_2, 64, 3, 3, 3, padding='same', name='Conv3d_4c_2b_3x3')

    branch_3 = MaxPooling3D((3, 3, 3), strides=(1, 1, 1), padding='same', name='MaxPool2d_4c_3a_3x3')(x)
    branch_3 = conv3d_bn(branch_3, 64, 1, 1, 1, padding='same', name='Conv3d_4c_3b_1x1')

    x = layers.concatenate(
        [branch_0, branch_1, branch_2, branch_3],
        axis=channel_axis,
        name='Mixed_4c')

    # Mixed 4d
    branch_0 = conv3d_bn(x, 128, 1, 1, 1, padding='same', name='Conv3d_4d_0a_1x1')

    branch_1 = conv3d_bn(x, 128, 1, 1, 1, padding='same', name='Conv3d_4d_1a_1x1')
    branch_1 = conv3d_bn(branch_1, 256, 3, 3, 3, padding='same', name='Conv3d_4d_1b_3x3')

    branch_2 = conv3d_bn(x, 24, 1, 1, 1, padding='same', name='Conv3d_4d_2a_1x1')
    branch_2 = conv3d_bn(branch_2, 64, 3, 3, 3, padding='same', name='Conv3d_4d_2b_3x3')

    branch_3 = MaxPooling3D((3, 3, 3), strides=(1, 1, 1), padding='same', name='MaxPool2d_4d_3a_3x3')(x)
    branch_3 = conv3d_bn(branch_3, 64, 1, 1, 1, padding='same', name='Conv3d_4d_3b_1x1')

    x = layers.concatenate(
        [branch_0, branch_1, branch_2, branch_3],
        axis=channel_axis,
        name='Mixed_4d')

    # Mixed 4e
    branch_0 = conv3d_bn(x, 112, 1, 1, 1, padding='same', name='Conv3d_4e_0a_1x1')

    branch_1 = conv3d_bn(x, 144, 1, 1, 1, padding='same', name='Conv3d_4e_1a_1x1')
    branch_1 = conv3d_bn(branch_1, 288, 3, 3, 3, padding='same', name='Conv3d_4e_1b_3x3')

    branch_2 = conv3d_bn(x, 32, 1, 1, 1, padding='same', name='Conv3d_4e_2a_1x1')
    branch_2 = conv3d_bn(branch_2, 64, 3, 3, 3, padding='same', name='Conv3d_4e_2b_3x3')

    branch_3 = MaxPooling3D((3, 3, 3), strides=(1, 1, 1), padding='same', name='MaxPool2d_4e_3a_3x3')(x)
    branch_3 = conv3d_bn(branch_3, 64, 1, 1, 1, padding='same', name='Conv3d_4e_3b_1x1')

    x = layers.concatenate(
        [branch_0, branch_1, branch_2, branch_3],
        axis=channel_axis,
        name='Mixed_4e')

    # Mixed 4f
    branch_0 = conv3d_bn(x, 256, 1, 1, 1, padding='same', name='Conv3d_4f_0a_1x1')

    branch_1 = conv3d_bn(x, 160, 1, 1, 1, padding='same', name='Conv3d_4f_1a_1x1')
    branch_1 = conv3d_bn(branch_1, 320, 3, 3, 3, padding='same', name='Conv3d_4f_1b_3x3')

    branch_2 = conv3d_bn(x, 32, 1, 1, 1, padding='same', name='Conv3d_4f_2a_1x1')
    branch_2 = conv3d_bn(branch_2, 128, 3, 3, 3, padding='same', name='Conv3d_4f_2b_3x3')

    branch_3 = MaxPooling3D((3, 3, 3), strides=(1, 1, 1), padding='same', name='MaxPool2d_4f_3a_3x3')(x)
    branch_3 = conv3d_bn(branch_3, 128, 1, 1, 1, padding='same', name='Conv3d_4f_3b_1x1')

    x = layers.concatenate(
        [branch_0, branch_1, branch_2, branch_3],
        axis=channel_axis,
        name='Mixed_4f')


    # Downsampling (spatial and temporal)
    x = MaxPooling3D((2, 2, 2), strides=(2, 2, 2), padding='same', name='MaxPool2d_5a_2x2')(x)

    # Mixed 5b
    branch_0 = conv3d_bn(x, 256, 1, 1, 1, padding='same', name='Conv3d_5b_0a_1x1')

    branch_1 = conv3d_bn(x, 160, 1, 1, 1, padding='same', name='Conv3d_5b_1a_1x1')
    branch_1 = conv3d_bn(branch_1, 320, 3, 3, 3, padding='same', name='Conv3d_5b_1b_3x3')

    branch_2 = conv3d_bn(x, 32, 1, 1, 1, padding='same', name='Conv3d_5b_2a_1x1')
    branch_2 = conv3d_bn(branch_2, 128, 3, 3, 3, padding='same', name='Conv3d_5b_2b_3x3')

    branch_3 = MaxPooling3D((3, 3, 3), strides=(1, 1, 1), padding='same', name='MaxPool2d_5b_3a_3x3')(x)
    branch_3 = conv3d_bn(branch_3, 128, 1, 1, 1, padding='same', name='Conv3d_5b_3b_1x1')

    x = layers.concatenate(
        [branch_0, branch_1, branch_2, branch_3],
        axis=channel_axis,
        name='Mixed_5b')

    # Mixed 5c
    branch_0 = conv3d_bn(x, 384, 1, 1, 1, padding='same', name='Conv3d_5c_0a_1x1')

    branch_1 = conv3d_bn(x, 192, 1, 1, 1, padding='same', name='Conv3d_5c_1a_1x1')
    branch_1 = conv3d_bn(branch_1, 384, 3, 3, 3, padding='same', name='Conv3d_5c_1b_3x3')

    branch_2 = conv3d_bn(x, 48, 1, 1, 1, padding='same', name='Conv3d_5c_2a_1x1')
    branch_2 = conv3d_bn(branch_2, 128, 3, 3, 3, padding='same', name='Conv3d_5c_2b_3x3')

    branch_3 = MaxPooling3D((3, 3, 3), strides=(1, 1, 1), padding='same', name='MaxPool2d_5c_3a_3x3')(x)
    branch_3 = conv3d_bn(branch_3, 128, 1, 1, 1, padding='same', name='Conv3d_5c_3b_1x1')

    x = layers.concatenate(
        [branch_0, branch_1, branch_2, branch_3],
        axis=channel_axis,
        name='Mixed_5c')

    if include_top:
        # Classification block
        x = AveragePooling3D((2, 7, 7), strides=(1, 1, 1), padding='valid', name='global_avg_pool')(x)
        x = Dropout(dropout_prob)(x)

        x = conv3d_bn(x, classes, 1, 1, 1, padding='same', 
                use_bias=True, use_activation_fn=False, use_bn=False, name='Conv3d_6a_1x1')
 
        num_frames_remaining = int(x.shape[1])
        x = Reshape((num_frames_remaining, classes))(x)

        # logits (raw scores for each class)
        x = Lambda(lambda x: K.mean(x, axis=1, keepdims=False),
                   output_shape=lambda s: (s[0], s[2]))(x)

        if not endpoint_logit:
            x = Activation('softmax', name='prediction')(x)
    else:
        h = int(x.shape[2])
        w = int(x.shape[3])
        x = AveragePooling3D((2, h, w), strides=(1, 1, 1), padding='valid', name='global_avg_pool')(x)



    inputs = img_input
    # create model
    model = Model(inputs, x, name='i3d_inception')

    # load weights
    if weights in WEIGHTS_NAME:
        if weights == WEIGHTS_NAME[0]:   # rgb_kinetics_only
            if include_top:
                weights_url = WEIGHTS_PATH['rgb_kinetics_only']
                model_name = 'i3d_inception_rgb_kinetics_only.h5'
            else:
                weights_url = WEIGHTS_PATH_NO_TOP['rgb_kinetics_only']
                model_name = 'i3d_inception_rgb_kinetics_only_no_top.h5'

        elif weights == WEIGHTS_NAME[1]: # flow_kinetics_only
            if include_top:
                weights_url = WEIGHTS_PATH['flow_kinetics_only']
                model_name = 'i3d_inception_flow_kinetics_only.h5'
            else:
                weights_url = WEIGHTS_PATH_NO_TOP['flow_kinetics_only']
                model_name = 'i3d_inception_flow_kinetics_only_no_top.h5'

        elif weights == WEIGHTS_NAME[2]: # rgb_imagenet_and_kinetics
            if include_top:
                weights_url = WEIGHTS_PATH['rgb_imagenet_and_kinetics']
                model_name = 'i3d_inception_rgb_imagenet_and_kinetics.h5'
            else:
                weights_url = WEIGHTS_PATH_NO_TOP['rgb_imagenet_and_kinetics']
                model_name = 'i3d_inception_rgb_imagenet_and_kinetics_no_top.h5'

        elif weights == WEIGHTS_NAME[3]: # flow_imagenet_and_kinetics
            if include_top:
                weights_url = WEIGHTS_PATH['flow_imagenet_and_kinetics']
                model_name = 'i3d_inception_flow_imagenet_and_kinetics.h5'
            else:
                weights_url = WEIGHTS_PATH_NO_TOP['flow_imagenet_and_kinetics']
                model_name = 'i3d_inception_flow_imagenet_and_kinetics_no_top.h5'

        downloaded_weights_path = get_file(model_name, weights_url, cache_subdir='models')
        model.load_weights(downloaded_weights_path)

        if K.backend() == 'theano':
            layer_utils.convert_all_kernels_in_model(model)

        if K.image_data_format() == 'channels_first' and K.backend() == 'tensorflow':
            warnings.warn('You are using the TensorFlow backend, yet you '
                          'are using the Theano '
                          'image data format convention '
                          '(`image_data_format="channels_first"`). '
                          'For best performance, set '
                          '`image_data_format="channels_last"` in '
                          'your keras config '
                          'at ~/.keras/keras.json.')

    elif weights is not None:
        model.load_weights(weights)

    return model

# %%
model_i3d_feature_extract = Inception_Inflated3d(include_top=False,
                weights='rgb_imagenet_and_kinetics',
                input_shape=(16,224,224,3),
                dropout_prob=0.0,
                endpoint_logit=True,
                classes=400)

# %%
model_i3d_feature_extract.summary()
# Out:
# Model: "i3d_inception"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 16, 224, 22  0           []
#                                 4, 3)]
#
#  Conv3d_1a_7x7_conv (Conv3D)    (None, 8, 112, 112,  65856       ['input_1[0][0]']
#                                  64)
#
#  Conv3d_1a_7x7_bn (BatchNormali  (None, 8, 112, 112,  192        ['Conv3d_1a_7x7_conv[0][0]']
#  zation)                         64)
#
#  Conv3d_1a_7x7 (Activation)     (None, 8, 112, 112,  0           ['Conv3d_1a_7x7_bn[0][0]']
#                                  64)
#
#  MaxPool2d_2a_3x3 (MaxPooling3D  (None, 8, 56, 56, 6  0          ['Conv3d_1a_7x7[0][0]']
#  )                              4)
#
#  Conv3d_2b_1x1_conv (Conv3D)    (None, 8, 56, 56, 6  4096        ['MaxPool2d_2a_3x3[0][0]']
#                                 4)
#
#  Conv3d_2b_1x1_bn (BatchNormali  (None, 8, 56, 56, 6  192        ['Conv3d_2b_1x1_conv[0][0]']
#  zation)                        4)
#
#  Conv3d_2b_1x1 (Activation)     (None, 8, 56, 56, 6  0           ['Conv3d_2b_1x1_bn[0][0]']
#                                 4)
#
#  Conv3d_2c_3x3_conv (Conv3D)    (None, 8, 56, 56, 1  331776      ['Conv3d_2b_1x1[0][0]']
#                                 92)
#
#  Conv3d_2c_3x3_bn (BatchNormali  (None, 8, 56, 56, 1  576        ['Conv3d_2c_3x3_conv[0][0]']
#  zation)                        92)
#
#  Conv3d_2c_3x3 (Activation)     (None, 8, 56, 56, 1  0           ['Conv3d_2c_3x3_bn[0][0]']
#                                 92)
#
#  MaxPool2d_3a_3x3 (MaxPooling3D  (None, 8, 28, 28, 1  0          ['Conv3d_2c_3x3[0][0]']
#  )                              92)
#
#  Conv3d_3b_1a_1x1_conv (Conv3D)  (None, 8, 28, 28, 9  18432      ['MaxPool2d_3a_3x3[0][0]']
#                                 6)
#
#  Conv3d_3b_2a_1x1_conv (Conv3D)  (None, 8, 28, 28, 1  3072       ['MaxPool2d_3a_3x3[0][0]']
#                                 6)
#
#  Conv3d_3b_1a_1x1_bn (BatchNorm  (None, 8, 28, 28, 9  288        ['Conv3d_3b_1a_1x1_conv[0][0]']
#  alization)                     6)
#
#  Conv3d_3b_2a_1x1_bn (BatchNorm  (None, 8, 28, 28, 1  48         ['Conv3d_3b_2a_1x1_conv[0][0]']
#  alization)                     6)
#
#  Conv3d_3b_1a_1x1 (Activation)  (None, 8, 28, 28, 9  0           ['Conv3d_3b_1a_1x1_bn[0][0]']
#                                 6)
#
#  Conv3d_3b_2a_1x1 (Activation)  (None, 8, 28, 28, 1  0           ['Conv3d_3b_2a_1x1_bn[0][0]']
#                                 6)
#
#  MaxPool2d_3b_3a_3x3 (MaxPoolin  (None, 8, 28, 28, 1  0          ['MaxPool2d_3a_3x3[0][0]']
#  g3D)                           92)
#
#  Conv3d_3b_0a_1x1_conv (Conv3D)  (None, 8, 28, 28, 6  12288      ['MaxPool2d_3a_3x3[0][0]']
#                                 4)
#
#  Conv3d_3b_1b_3x3_conv (Conv3D)  (None, 8, 28, 28, 1  331776     ['Conv3d_3b_1a_1x1[0][0]']
#                                 28)
#
#  Conv3d_3b_2b_3x3_conv (Conv3D)  (None, 8, 28, 28, 3  13824      ['Conv3d_3b_2a_1x1[0][0]']
#                                 2)
#
#  Conv3d_3b_3b_1x1_conv (Conv3D)  (None, 8, 28, 28, 3  6144       ['MaxPool2d_3b_3a_3x3[0][0]']
#                                 2)
#
#  Conv3d_3b_0a_1x1_bn (BatchNorm  (None, 8, 28, 28, 6  192        ['Conv3d_3b_0a_1x1_conv[0][0]']
#  alization)                     4)
#
#  Conv3d_3b_1b_3x3_bn (BatchNorm  (None, 8, 28, 28, 1  384        ['Conv3d_3b_1b_3x3_conv[0][0]']
#  alization)                     28)
#
#  Conv3d_3b_2b_3x3_bn (BatchNorm  (None, 8, 28, 28, 3  96         ['Conv3d_3b_2b_3x3_conv[0][0]']
#  alization)                     2)
#
#  Conv3d_3b_3b_1x1_bn (BatchNorm  (None, 8, 28, 28, 3  96         ['Conv3d_3b_3b_1x1_conv[0][0]']
#  alization)                     2)
#
#  Conv3d_3b_0a_1x1 (Activation)  (None, 8, 28, 28, 6  0           ['Conv3d_3b_0a_1x1_bn[0][0]']
#                                 4)
#
#  Conv3d_3b_1b_3x3 (Activation)  (None, 8, 28, 28, 1  0           ['Conv3d_3b_1b_3x3_bn[0][0]']
#                                 28)
#
#  Conv3d_3b_2b_3x3 (Activation)  (None, 8, 28, 28, 3  0           ['Conv3d_3b_2b_3x3_bn[0][0]']
#                                 2)
#
#  Conv3d_3b_3b_1x1 (Activation)  (None, 8, 28, 28, 3  0           ['Conv3d_3b_3b_1x1_bn[0][0]']
#                                 2)
#
#  Mixed_3b (Concatenate)         (None, 8, 28, 28, 2  0           ['Conv3d_3b_0a_1x1[0][0]',
#                                 56)                               'Conv3d_3b_1b_3x3[0][0]',
#                                                                   'Conv3d_3b_2b_3x3[0][0]',
#                                                                   'Conv3d_3b_3b_1x1[0][0]']
#
#  Conv3d_3c_1a_1x1_conv (Conv3D)  (None, 8, 28, 28, 1  32768      ['Mixed_3b[0][0]']
#                                 28)
#
#  Conv3d_3c_2a_1x1_conv (Conv3D)  (None, 8, 28, 28, 3  8192       ['Mixed_3b[0][0]']
#                                 2)
#
#  Conv3d_3c_1a_1x1_bn (BatchNorm  (None, 8, 28, 28, 1  384        ['Conv3d_3c_1a_1x1_conv[0][0]']
#  alization)                     28)
#
#  Conv3d_3c_2a_1x1_bn (BatchNorm  (None, 8, 28, 28, 3  96         ['Conv3d_3c_2a_1x1_conv[0][0]']
#  alization)                     2)
#
#  Conv3d_3c_1a_1x1 (Activation)  (None, 8, 28, 28, 1  0           ['Conv3d_3c_1a_1x1_bn[0][0]']
#                                 28)
#
#  Conv3d_3c_2a_1x1 (Activation)  (None, 8, 28, 28, 3  0           ['Conv3d_3c_2a_1x1_bn[0][0]']
#                                 2)
#
#  MaxPool2d_3c_3a_3x3 (MaxPoolin  (None, 8, 28, 28, 2  0          ['Mixed_3b[0][0]']
#  g3D)                           56)
#
#  Conv3d_3c_0a_1x1_conv (Conv3D)  (None, 8, 28, 28, 1  32768      ['Mixed_3b[0][0]']
#                                 28)
#
#  Conv3d_3c_1b_3x3_conv (Conv3D)  (None, 8, 28, 28, 1  663552     ['Conv3d_3c_1a_1x1[0][0]']
#                                 92)
#
#  Conv3d_3c_2b_3x3_conv (Conv3D)  (None, 8, 28, 28, 9  82944      ['Conv3d_3c_2a_1x1[0][0]']
#                                 6)
#
#  Conv3d_3c_3b_1x1_conv (Conv3D)  (None, 8, 28, 28, 6  16384      ['MaxPool2d_3c_3a_3x3[0][0]']
#                                 4)
#
#  Conv3d_3c_0a_1x1_bn (BatchNorm  (None, 8, 28, 28, 1  384        ['Conv3d_3c_0a_1x1_conv[0][0]']
#  alization)                     28)
#
#  Conv3d_3c_1b_3x3_bn (BatchNorm  (None, 8, 28, 28, 1  576        ['Conv3d_3c_1b_3x3_conv[0][0]']
#  alization)                     92)
#
#  Conv3d_3c_2b_3x3_bn (BatchNorm  (None, 8, 28, 28, 9  288        ['Conv3d_3c_2b_3x3_conv[0][0]']
#  alization)                     6)
#
#  Conv3d_3c_3b_1x1_bn (BatchNorm  (None, 8, 28, 28, 6  192        ['Conv3d_3c_3b_1x1_conv[0][0]']
#  alization)                     4)
#
#  Conv3d_3c_0a_1x1 (Activation)  (None, 8, 28, 28, 1  0           ['Conv3d_3c_0a_1x1_bn[0][0]']
#                                 28)
#
#  Conv3d_3c_1b_3x3 (Activation)  (None, 8, 28, 28, 1  0           ['Conv3d_3c_1b_3x3_bn[0][0]']
#                                 92)
#
#  Conv3d_3c_2b_3x3 (Activation)  (None, 8, 28, 28, 9  0           ['Conv3d_3c_2b_3x3_bn[0][0]']
#                                 6)
#
#  Conv3d_3c_3b_1x1 (Activation)  (None, 8, 28, 28, 6  0           ['Conv3d_3c_3b_1x1_bn[0][0]']
#                                 4)
#
#  Mixed_3c (Concatenate)         (None, 8, 28, 28, 4  0           ['Conv3d_3c_0a_1x1[0][0]',
#                                 80)                               'Conv3d_3c_1b_3x3[0][0]',
#                                                                   'Conv3d_3c_2b_3x3[0][0]',
#                                                                   'Conv3d_3c_3b_1x1[0][0]']
#
#  MaxPool2d_4a_3x3 (MaxPooling3D  (None, 4, 14, 14, 4  0          ['Mixed_3c[0][0]']
#  )                              80)
#
#  Conv3d_4b_1a_1x1_conv (Conv3D)  (None, 4, 14, 14, 9  46080      ['MaxPool2d_4a_3x3[0][0]']
#                                 6)
#
#  Conv3d_4b_2a_1x1_conv (Conv3D)  (None, 4, 14, 14, 1  7680       ['MaxPool2d_4a_3x3[0][0]']
#                                 6)
#
#  Conv3d_4b_1a_1x1_bn (BatchNorm  (None, 4, 14, 14, 9  288        ['Conv3d_4b_1a_1x1_conv[0][0]']
#  alization)                     6)
#
#  Conv3d_4b_2a_1x1_bn (BatchNorm  (None, 4, 14, 14, 1  48         ['Conv3d_4b_2a_1x1_conv[0][0]']
#  alization)                     6)
#
#  Conv3d_4b_1a_1x1 (Activation)  (None, 4, 14, 14, 9  0           ['Conv3d_4b_1a_1x1_bn[0][0]']
#                                 6)
#
#  Conv3d_4b_2a_1x1 (Activation)  (None, 4, 14, 14, 1  0           ['Conv3d_4b_2a_1x1_bn[0][0]']
#                                 6)
#
#  MaxPool2d_4b_3a_3x3 (MaxPoolin  (None, 4, 14, 14, 4  0          ['MaxPool2d_4a_3x3[0][0]']
#  g3D)                           80)
#
#  Conv3d_4b_0a_1x1_conv (Conv3D)  (None, 4, 14, 14, 1  92160      ['MaxPool2d_4a_3x3[0][0]']
#                                 92)
#
#  Conv3d_4b_1b_3x3_conv (Conv3D)  (None, 4, 14, 14, 2  539136     ['Conv3d_4b_1a_1x1[0][0]']
#                                 08)
#
#  Conv3d_4b_2b_3x3_conv (Conv3D)  (None, 4, 14, 14, 4  20736      ['Conv3d_4b_2a_1x1[0][0]']
#                                 8)
#
#  Conv3d_4b_3b_1x1_conv (Conv3D)  (None, 4, 14, 14, 6  30720      ['MaxPool2d_4b_3a_3x3[0][0]']
#                                 4)
#
#  Conv3d_4b_0a_1x1_bn (BatchNorm  (None, 4, 14, 14, 1  576        ['Conv3d_4b_0a_1x1_conv[0][0]']
#  alization)                     92)
#
#  Conv3d_4b_1b_3x3_bn (BatchNorm  (None, 4, 14, 14, 2  624        ['Conv3d_4b_1b_3x3_conv[0][0]']
#  alization)                     08)
#
#  Conv3d_4b_2b_3x3_bn (BatchNorm  (None, 4, 14, 14, 4  144        ['Conv3d_4b_2b_3x3_conv[0][0]']
#  alization)                     8)
#
#  Conv3d_4b_3b_1x1_bn (BatchNorm  (None, 4, 14, 14, 6  192        ['Conv3d_4b_3b_1x1_conv[0][0]']
#  alization)                     4)
#
#  Conv3d_4b_0a_1x1 (Activation)  (None, 4, 14, 14, 1  0           ['Conv3d_4b_0a_1x1_bn[0][0]']
#                                 92)
#
#  Conv3d_4b_1b_3x3 (Activation)  (None, 4, 14, 14, 2  0           ['Conv3d_4b_1b_3x3_bn[0][0]']
#                                 08)
#
#  Conv3d_4b_2b_3x3 (Activation)  (None, 4, 14, 14, 4  0           ['Conv3d_4b_2b_3x3_bn[0][0]']
#                                 8)
#
#  Conv3d_4b_3b_1x1 (Activation)  (None, 4, 14, 14, 6  0           ['Conv3d_4b_3b_1x1_bn[0][0]']
#                                 4)
#
#  Mixed_4b (Concatenate)         (None, 4, 14, 14, 5  0           ['Conv3d_4b_0a_1x1[0][0]',
#                                 12)                               'Conv3d_4b_1b_3x3[0][0]',
#                                                                   'Conv3d_4b_2b_3x3[0][0]',
#                                                                   'Conv3d_4b_3b_1x1[0][0]']
#
#  Conv3d_4c_1a_1x1_conv (Conv3D)  (None, 4, 14, 14, 1  57344      ['Mixed_4b[0][0]']
#                                 12)
#
#  Conv3d_4c_2a_1x1_conv (Conv3D)  (None, 4, 14, 14, 2  12288      ['Mixed_4b[0][0]']
#                                 4)
#
#  Conv3d_4c_1a_1x1_bn (BatchNorm  (None, 4, 14, 14, 1  336        ['Conv3d_4c_1a_1x1_conv[0][0]']
#  alization)                     12)
#
#  Conv3d_4c_2a_1x1_bn (BatchNorm  (None, 4, 14, 14, 2  72         ['Conv3d_4c_2a_1x1_conv[0][0]']
#  alization)                     4)
#
#  Conv3d_4c_1a_1x1 (Activation)  (None, 4, 14, 14, 1  0           ['Conv3d_4c_1a_1x1_bn[0][0]']
#                                 12)
#
#  Conv3d_4c_2a_1x1 (Activation)  (None, 4, 14, 14, 2  0           ['Conv3d_4c_2a_1x1_bn[0][0]']
#                                 4)
#
#  MaxPool2d_4c_3a_3x3 (MaxPoolin  (None, 4, 14, 14, 5  0          ['Mixed_4b[0][0]']
#  g3D)                           12)
#
#  Conv3d_4c_0a_1x1_conv (Conv3D)  (None, 4, 14, 14, 1  81920      ['Mixed_4b[0][0]']
#                                 60)
#
#  Conv3d_4c_1b_3x3_conv (Conv3D)  (None, 4, 14, 14, 2  677376     ['Conv3d_4c_1a_1x1[0][0]']
#                                 24)
#
#  Conv3d_4c_2b_3x3_conv (Conv3D)  (None, 4, 14, 14, 6  41472      ['Conv3d_4c_2a_1x1[0][0]']
#                                 4)
#
#  Conv3d_4c_3b_1x1_conv (Conv3D)  (None, 4, 14, 14, 6  32768      ['MaxPool2d_4c_3a_3x3[0][0]']
#                                 4)
#
#  Conv3d_4c_0a_1x1_bn (BatchNorm  (None, 4, 14, 14, 1  480        ['Conv3d_4c_0a_1x1_conv[0][0]']
#  alization)                     60)
#
#  Conv3d_4c_1b_3x3_bn (BatchNorm  (None, 4, 14, 14, 2  672        ['Conv3d_4c_1b_3x3_conv[0][0]']
#  alization)                     24)
#
#  Conv3d_4c_2b_3x3_bn (BatchNorm  (None, 4, 14, 14, 6  192        ['Conv3d_4c_2b_3x3_conv[0][0]']
#  alization)                     4)
#
#  Conv3d_4c_3b_1x1_bn (BatchNorm  (None, 4, 14, 14, 6  192        ['Conv3d_4c_3b_1x1_conv[0][0]']
#  alization)                     4)
#
#  Conv3d_4c_0a_1x1 (Activation)  (None, 4, 14, 14, 1  0           ['Conv3d_4c_0a_1x1_bn[0][0]']
#                                 60)
#
#  Conv3d_4c_1b_3x3 (Activation)  (None, 4, 14, 14, 2  0           ['Conv3d_4c_1b_3x3_bn[0][0]']
#                                 24)
#
#  Conv3d_4c_2b_3x3 (Activation)  (None, 4, 14, 14, 6  0           ['Conv3d_4c_2b_3x3_bn[0][0]']
#                                 4)
#
#  Conv3d_4c_3b_1x1 (Activation)  (None, 4, 14, 14, 6  0           ['Conv3d_4c_3b_1x1_bn[0][0]']
#                                 4)
#
#  Mixed_4c (Concatenate)         (None, 4, 14, 14, 5  0           ['Conv3d_4c_0a_1x1[0][0]',
#                                 12)                               'Conv3d_4c_1b_3x3[0][0]',
#                                                                   'Conv3d_4c_2b_3x3[0][0]',
#                                                                   'Conv3d_4c_3b_1x1[0][0]']
#
#  Conv3d_4d_1a_1x1_conv (Conv3D)  (None, 4, 14, 14, 1  65536      ['Mixed_4c[0][0]']
#                                 28)
#
#  Conv3d_4d_2a_1x1_conv (Conv3D)  (None, 4, 14, 14, 2  12288      ['Mixed_4c[0][0]']
#                                 4)
#
#  Conv3d_4d_1a_1x1_bn (BatchNorm  (None, 4, 14, 14, 1  384        ['Conv3d_4d_1a_1x1_conv[0][0]']
#  alization)                     28)
#
#  Conv3d_4d_2a_1x1_bn (BatchNorm  (None, 4, 14, 14, 2  72         ['Conv3d_4d_2a_1x1_conv[0][0]']
#  alization)                     4)
#
#  Conv3d_4d_1a_1x1 (Activation)  (None, 4, 14, 14, 1  0           ['Conv3d_4d_1a_1x1_bn[0][0]']
#                                 28)
#
#  Conv3d_4d_2a_1x1 (Activation)  (None, 4, 14, 14, 2  0           ['Conv3d_4d_2a_1x1_bn[0][0]']
#                                 4)
#
#  MaxPool2d_4d_3a_3x3 (MaxPoolin  (None, 4, 14, 14, 5  0          ['Mixed_4c[0][0]']
#  g3D)                           12)
#
#  Conv3d_4d_0a_1x1_conv (Conv3D)  (None, 4, 14, 14, 1  65536      ['Mixed_4c[0][0]']
#                                 28)
#
#  Conv3d_4d_1b_3x3_conv (Conv3D)  (None, 4, 14, 14, 2  884736     ['Conv3d_4d_1a_1x1[0][0]']
#                                 56)
#
#  Conv3d_4d_2b_3x3_conv (Conv3D)  (None, 4, 14, 14, 6  41472      ['Conv3d_4d_2a_1x1[0][0]']
#                                 4)
#
#  Conv3d_4d_3b_1x1_conv (Conv3D)  (None, 4, 14, 14, 6  32768      ['MaxPool2d_4d_3a_3x3[0][0]']
#                                 4)
#
#  Conv3d_4d_0a_1x1_bn (BatchNorm  (None, 4, 14, 14, 1  384        ['Conv3d_4d_0a_1x1_conv[0][0]']
#  alization)                     28)
#
#  Conv3d_4d_1b_3x3_bn (BatchNorm  (None, 4, 14, 14, 2  768        ['Conv3d_4d_1b_3x3_conv[0][0]']
#  alization)                     56)
#
#  Conv3d_4d_2b_3x3_bn (BatchNorm  (None, 4, 14, 14, 6  192        ['Conv3d_4d_2b_3x3_conv[0][0]']
#  alization)                     4)
#
#  Conv3d_4d_3b_1x1_bn (BatchNorm  (None, 4, 14, 14, 6  192        ['Conv3d_4d_3b_1x1_conv[0][0]']
#  alization)                     4)
#
#  Conv3d_4d_0a_1x1 (Activation)  (None, 4, 14, 14, 1  0           ['Conv3d_4d_0a_1x1_bn[0][0]']
#                                 28)
#
#  Conv3d_4d_1b_3x3 (Activation)  (None, 4, 14, 14, 2  0           ['Conv3d_4d_1b_3x3_bn[0][0]']
#                                 56)
#
#  Conv3d_4d_2b_3x3 (Activation)  (None, 4, 14, 14, 6  0           ['Conv3d_4d_2b_3x3_bn[0][0]']
#                                 4)
#
#  Conv3d_4d_3b_1x1 (Activation)  (None, 4, 14, 14, 6  0           ['Conv3d_4d_3b_1x1_bn[0][0]']
#                                 4)
#
#  Mixed_4d (Concatenate)         (None, 4, 14, 14, 5  0           ['Conv3d_4d_0a_1x1[0][0]',
#                                 12)                               'Conv3d_4d_1b_3x3[0][0]',
#                                                                   'Conv3d_4d_2b_3x3[0][0]',
#                                                                   'Conv3d_4d_3b_1x1[0][0]']
#
#  Conv3d_4e_1a_1x1_conv (Conv3D)  (None, 4, 14, 14, 1  73728      ['Mixed_4d[0][0]']
#                                 44)
#
#  Conv3d_4e_2a_1x1_conv (Conv3D)  (None, 4, 14, 14, 3  16384      ['Mixed_4d[0][0]']
#                                 2)
#
#  Conv3d_4e_1a_1x1_bn (BatchNorm  (None, 4, 14, 14, 1  432        ['Conv3d_4e_1a_1x1_conv[0][0]']
#  alization)                     44)
#
#  Conv3d_4e_2a_1x1_bn (BatchNorm  (None, 4, 14, 14, 3  96         ['Conv3d_4e_2a_1x1_conv[0][0]']
#  alization)                     2)
#
#  Conv3d_4e_1a_1x1 (Activation)  (None, 4, 14, 14, 1  0           ['Conv3d_4e_1a_1x1_bn[0][0]']
#                                 44)
#
#  Conv3d_4e_2a_1x1 (Activation)  (None, 4, 14, 14, 3  0           ['Conv3d_4e_2a_1x1_bn[0][0]']
#                                 2)
#
#  MaxPool2d_4e_3a_3x3 (MaxPoolin  (None, 4, 14, 14, 5  0          ['Mixed_4d[0][0]']
#  g3D)                           12)
#
#  Conv3d_4e_0a_1x1_conv (Conv3D)  (None, 4, 14, 14, 1  57344      ['Mixed_4d[0][0]']
#                                 12)
#
#  Conv3d_4e_1b_3x3_conv (Conv3D)  (None, 4, 14, 14, 2  1119744    ['Conv3d_4e_1a_1x1[0][0]']
#                                 88)
#
#  Conv3d_4e_2b_3x3_conv (Conv3D)  (None, 4, 14, 14, 6  55296      ['Conv3d_4e_2a_1x1[0][0]']
#                                 4)
#
#  Conv3d_4e_3b_1x1_conv (Conv3D)  (None, 4, 14, 14, 6  32768      ['MaxPool2d_4e_3a_3x3[0][0]']
#                                 4)
#
#  Conv3d_4e_0a_1x1_bn (BatchNorm  (None, 4, 14, 14, 1  336        ['Conv3d_4e_0a_1x1_conv[0][0]']
#  alization)                     12)
#
#  Conv3d_4e_1b_3x3_bn (BatchNorm  (None, 4, 14, 14, 2  864        ['Conv3d_4e_1b_3x3_conv[0][0]']
#  alization)                     88)
#
#  Conv3d_4e_2b_3x3_bn (BatchNorm  (None, 4, 14, 14, 6  192        ['Conv3d_4e_2b_3x3_conv[0][0]']
#  alization)                     4)
#
#  Conv3d_4e_3b_1x1_bn (BatchNorm  (None, 4, 14, 14, 6  192        ['Conv3d_4e_3b_1x1_conv[0][0]']
#  alization)                     4)
#
#  Conv3d_4e_0a_1x1 (Activation)  (None, 4, 14, 14, 1  0           ['Conv3d_4e_0a_1x1_bn[0][0]']
#                                 12)
#
#  Conv3d_4e_1b_3x3 (Activation)  (None, 4, 14, 14, 2  0           ['Conv3d_4e_1b_3x3_bn[0][0]']
#                                 88)
#
#  Conv3d_4e_2b_3x3 (Activation)  (None, 4, 14, 14, 6  0           ['Conv3d_4e_2b_3x3_bn[0][0]']
#                                 4)
#
#  Conv3d_4e_3b_1x1 (Activation)  (None, 4, 14, 14, 6  0           ['Conv3d_4e_3b_1x1_bn[0][0]']
#                                 4)
#
#  Mixed_4e (Concatenate)         (None, 4, 14, 14, 5  0           ['Conv3d_4e_0a_1x1[0][0]',
#                                 28)                               'Conv3d_4e_1b_3x3[0][0]',
#                                                                   'Conv3d_4e_2b_3x3[0][0]',
#                                                                   'Conv3d_4e_3b_1x1[0][0]']
#
#  Conv3d_4f_1a_1x1_conv (Conv3D)  (None, 4, 14, 14, 1  84480      ['Mixed_4e[0][0]']
#                                 60)
#
#  Conv3d_4f_2a_1x1_conv (Conv3D)  (None, 4, 14, 14, 3  16896      ['Mixed_4e[0][0]']
#                                 2)
#
#  Conv3d_4f_1a_1x1_bn (BatchNorm  (None, 4, 14, 14, 1  480        ['Conv3d_4f_1a_1x1_conv[0][0]']
#  alization)                     60)
#
#  Conv3d_4f_2a_1x1_bn (BatchNorm  (None, 4, 14, 14, 3  96         ['Conv3d_4f_2a_1x1_conv[0][0]']
#  alization)                     2)
#
#  Conv3d_4f_1a_1x1 (Activation)  (None, 4, 14, 14, 1  0           ['Conv3d_4f_1a_1x1_bn[0][0]']
#                                 60)
#
#  Conv3d_4f_2a_1x1 (Activation)  (None, 4, 14, 14, 3  0           ['Conv3d_4f_2a_1x1_bn[0][0]']
#                                 2)
#
#  MaxPool2d_4f_3a_3x3 (MaxPoolin  (None, 4, 14, 14, 5  0          ['Mixed_4e[0][0]']
#  g3D)                           28)
#
#  Conv3d_4f_0a_1x1_conv (Conv3D)  (None, 4, 14, 14, 2  135168     ['Mixed_4e[0][0]']
#                                 56)
#
#  Conv3d_4f_1b_3x3_conv (Conv3D)  (None, 4, 14, 14, 3  1382400    ['Conv3d_4f_1a_1x1[0][0]']
#                                 20)
#
#  Conv3d_4f_2b_3x3_conv (Conv3D)  (None, 4, 14, 14, 1  110592     ['Conv3d_4f_2a_1x1[0][0]']
#                                 28)
#
#  Conv3d_4f_3b_1x1_conv (Conv3D)  (None, 4, 14, 14, 1  67584      ['MaxPool2d_4f_3a_3x3[0][0]']
#                                 28)
#
#  Conv3d_4f_0a_1x1_bn (BatchNorm  (None, 4, 14, 14, 2  768        ['Conv3d_4f_0a_1x1_conv[0][0]']
#  alization)                     56)
#
#  Conv3d_4f_1b_3x3_bn (BatchNorm  (None, 4, 14, 14, 3  960        ['Conv3d_4f_1b_3x3_conv[0][0]']
#  alization)                     20)
#
#  Conv3d_4f_2b_3x3_bn (BatchNorm  (None, 4, 14, 14, 1  384        ['Conv3d_4f_2b_3x3_conv[0][0]']
#  alization)                     28)
#
#  Conv3d_4f_3b_1x1_bn (BatchNorm  (None, 4, 14, 14, 1  384        ['Conv3d_4f_3b_1x1_conv[0][0]']
#  alization)                     28)
#
#  Conv3d_4f_0a_1x1 (Activation)  (None, 4, 14, 14, 2  0           ['Conv3d_4f_0a_1x1_bn[0][0]']
#                                 56)
#
#  Conv3d_4f_1b_3x3 (Activation)  (None, 4, 14, 14, 3  0           ['Conv3d_4f_1b_3x3_bn[0][0]']
#                                 20)
#
#  Conv3d_4f_2b_3x3 (Activation)  (None, 4, 14, 14, 1  0           ['Conv3d_4f_2b_3x3_bn[0][0]']
#                                 28)
#
#  Conv3d_4f_3b_1x1 (Activation)  (None, 4, 14, 14, 1  0           ['Conv3d_4f_3b_1x1_bn[0][0]']
#                                 28)
#
#  Mixed_4f (Concatenate)         (None, 4, 14, 14, 8  0           ['Conv3d_4f_0a_1x1[0][0]',
#                                 32)                               'Conv3d_4f_1b_3x3[0][0]',
#                                                                   'Conv3d_4f_2b_3x3[0][0]',
#                                                                   'Conv3d_4f_3b_1x1[0][0]']
#
#  MaxPool2d_5a_2x2 (MaxPooling3D  (None, 2, 7, 7, 832  0          ['Mixed_4f[0][0]']
#  )                              )
#
#  Conv3d_5b_1a_1x1_conv (Conv3D)  (None, 2, 7, 7, 160  133120     ['MaxPool2d_5a_2x2[0][0]']
#                                 )
#
#  Conv3d_5b_2a_1x1_conv (Conv3D)  (None, 2, 7, 7, 32)  26624      ['MaxPool2d_5a_2x2[0][0]']
#
#  Conv3d_5b_1a_1x1_bn (BatchNorm  (None, 2, 7, 7, 160  480        ['Conv3d_5b_1a_1x1_conv[0][0]']
#  alization)                     )
#
#  Conv3d_5b_2a_1x1_bn (BatchNorm  (None, 2, 7, 7, 32)  96         ['Conv3d_5b_2a_1x1_conv[0][0]']
#  alization)
#
#  Conv3d_5b_1a_1x1 (Activation)  (None, 2, 7, 7, 160  0           ['Conv3d_5b_1a_1x1_bn[0][0]']
#                                 )
#
#  Conv3d_5b_2a_1x1 (Activation)  (None, 2, 7, 7, 32)  0           ['Conv3d_5b_2a_1x1_bn[0][0]']
#
#  MaxPool2d_5b_3a_3x3 (MaxPoolin  (None, 2, 7, 7, 832  0          ['MaxPool2d_5a_2x2[0][0]']
#  g3D)                           )
#
#  Conv3d_5b_0a_1x1_conv (Conv3D)  (None, 2, 7, 7, 256  212992     ['MaxPool2d_5a_2x2[0][0]']
#                                 )
#
#  Conv3d_5b_1b_3x3_conv (Conv3D)  (None, 2, 7, 7, 320  1382400    ['Conv3d_5b_1a_1x1[0][0]']
#                                 )
#
#  Conv3d_5b_2b_3x3_conv (Conv3D)  (None, 2, 7, 7, 128  110592     ['Conv3d_5b_2a_1x1[0][0]']
#                                 )
#
#  Conv3d_5b_3b_1x1_conv (Conv3D)  (None, 2, 7, 7, 128  106496     ['MaxPool2d_5b_3a_3x3[0][0]']
#                                 )
#
#  Conv3d_5b_0a_1x1_bn (BatchNorm  (None, 2, 7, 7, 256  768        ['Conv3d_5b_0a_1x1_conv[0][0]']
#  alization)                     )
#
#  Conv3d_5b_1b_3x3_bn (BatchNorm  (None, 2, 7, 7, 320  960        ['Conv3d_5b_1b_3x3_conv[0][0]']
#  alization)                     )
#
#  Conv3d_5b_2b_3x3_bn (BatchNorm  (None, 2, 7, 7, 128  384        ['Conv3d_5b_2b_3x3_conv[0][0]']
#  alization)                     )
#
#  Conv3d_5b_3b_1x1_bn (BatchNorm  (None, 2, 7, 7, 128  384        ['Conv3d_5b_3b_1x1_conv[0][0]']
#  alization)                     )
#
#  Conv3d_5b_0a_1x1 (Activation)  (None, 2, 7, 7, 256  0           ['Conv3d_5b_0a_1x1_bn[0][0]']
#                                 )
#
#  Conv3d_5b_1b_3x3 (Activation)  (None, 2, 7, 7, 320  0           ['Conv3d_5b_1b_3x3_bn[0][0]']
#                                 )
#
#  Conv3d_5b_2b_3x3 (Activation)  (None, 2, 7, 7, 128  0           ['Conv3d_5b_2b_3x3_bn[0][0]']
#                                 )
#
#  Conv3d_5b_3b_1x1 (Activation)  (None, 2, 7, 7, 128  0           ['Conv3d_5b_3b_1x1_bn[0][0]']
#                                 )
#
#  Mixed_5b (Concatenate)         (None, 2, 7, 7, 832  0           ['Conv3d_5b_0a_1x1[0][0]',
#                                 )                                 'Conv3d_5b_1b_3x3[0][0]',
#                                                                   'Conv3d_5b_2b_3x3[0][0]',
#                                                                   'Conv3d_5b_3b_1x1[0][0]']
#
#  Conv3d_5c_1a_1x1_conv (Conv3D)  (None, 2, 7, 7, 192  159744     ['Mixed_5b[0][0]']
#                                 )
#
#  Conv3d_5c_2a_1x1_conv (Conv3D)  (None, 2, 7, 7, 48)  39936      ['Mixed_5b[0][0]']
#
#  Conv3d_5c_1a_1x1_bn (BatchNorm  (None, 2, 7, 7, 192  576        ['Conv3d_5c_1a_1x1_conv[0][0]']
#  alization)                     )
#
#  Conv3d_5c_2a_1x1_bn (BatchNorm  (None, 2, 7, 7, 48)  144        ['Conv3d_5c_2a_1x1_conv[0][0]']
#  alization)
#
#  Conv3d_5c_1a_1x1 (Activation)  (None, 2, 7, 7, 192  0           ['Conv3d_5c_1a_1x1_bn[0][0]']
#                                 )
#
#  Conv3d_5c_2a_1x1 (Activation)  (None, 2, 7, 7, 48)  0           ['Conv3d_5c_2a_1x1_bn[0][0]']
#
#  MaxPool2d_5c_3a_3x3 (MaxPoolin  (None, 2, 7, 7, 832  0          ['Mixed_5b[0][0]']
#  g3D)                           )
#
#  Conv3d_5c_0a_1x1_conv (Conv3D)  (None, 2, 7, 7, 384  319488     ['Mixed_5b[0][0]']
#                                 )
#
#  Conv3d_5c_1b_3x3_conv (Conv3D)  (None, 2, 7, 7, 384  1990656    ['Conv3d_5c_1a_1x1[0][0]']
#                                 )
#
#  Conv3d_5c_2b_3x3_conv (Conv3D)  (None, 2, 7, 7, 128  165888     ['Conv3d_5c_2a_1x1[0][0]']
#                                 )
#
#  Conv3d_5c_3b_1x1_conv (Conv3D)  (None, 2, 7, 7, 128  106496     ['MaxPool2d_5c_3a_3x3[0][0]']
#                                 )
#
#  Conv3d_5c_0a_1x1_bn (BatchNorm  (None, 2, 7, 7, 384  1152       ['Conv3d_5c_0a_1x1_conv[0][0]']
#  alization)                     )
#
#  Conv3d_5c_1b_3x3_bn (BatchNorm  (None, 2, 7, 7, 384  1152       ['Conv3d_5c_1b_3x3_conv[0][0]']
#  alization)                     )
#
#  Conv3d_5c_2b_3x3_bn (BatchNorm  (None, 2, 7, 7, 128  384        ['Conv3d_5c_2b_3x3_conv[0][0]']
#  alization)                     )
#
#  Conv3d_5c_3b_1x1_bn (BatchNorm  (None, 2, 7, 7, 128  384        ['Conv3d_5c_3b_1x1_conv[0][0]']
#  alization)                     )
#
#  Conv3d_5c_0a_1x1 (Activation)  (None, 2, 7, 7, 384  0           ['Conv3d_5c_0a_1x1_bn[0][0]']
#                                 )
#
#  Conv3d_5c_1b_3x3 (Activation)  (None, 2, 7, 7, 384  0           ['Conv3d_5c_1b_3x3_bn[0][0]']
#                                 )
#
#  Conv3d_5c_2b_3x3 (Activation)  (None, 2, 7, 7, 128  0           ['Conv3d_5c_2b_3x3_bn[0][0]']
#                                 )
#
#  Conv3d_5c_3b_1x1 (Activation)  (None, 2, 7, 7, 128  0           ['Conv3d_5c_3b_1x1_bn[0][0]']
#                                 )
#
#  Mixed_5c (Concatenate)         (None, 2, 7, 7, 102  0           ['Conv3d_5c_0a_1x1[0][0]',
#                                 4)                                'Conv3d_5c_1b_3x3[0][0]',
#                                                                   'Conv3d_5c_2b_3x3[0][0]',
#                                                                   'Conv3d_5c_3b_1x1[0][0]']
#
#  global_avg_pool (AveragePoolin  (None, 1, 1, 1, 102  0          ['Mixed_5c[0][0]']
#  g3D)                           4)
#
# ==================================================================================================
# Total params: 12,294,544
# Trainable params: 12,279,984
# Non-trainable params: 14,560
# __________________________________________________________________________________________________

# %% [markdown]
# # Extract Features

# %% [markdown]
# ## Normal Videos

# %%
normal_videos = os.listdir(normal_videos_path)
normal_videos.sort()
chunk = list(divide_chunks(normal_videos, 5))
len(normal_videos)
# Out:
# 7

# %% [markdown]
# ### I3d

# %%
# print("Processing normal videos...")
# for vid_name in normal_videos:
#     print("Processing {}".format(vid_name))
#     vid_path = os.path.join(normal_videos_path, vid_name)
#     feats_path = os.path.join(
#         raw_normal_train_features_i3d, vid_name[:-9] + ".npy"
#     )

#     clips, frames = get_video_clips(vid_path, i3d_frame_count)

#     # Remove last clip if number of frames is not equal to 16
#     if frames % 16 != 0:
#         clips = clips[:-1]
    
#     print('Frames:   ',frames)
#     print('Len clips:',len(clips))
#     if frames > 1700 or frames < 500:
#       continue

#     prep_clips = [preprocess_input_i3d(np.array(clip)) for clip in clips]
#     prep_clips = np.vstack(prep_clips)

#     features = model_i3d_feature_extract(prep_clips)

#     features = np.reshape(features, (features.shape[0], features.shape[4]))
#     features = sklearn.preprocessing.normalize(features, axis=1)
#     del prep_clips
    
#     with open(feats_path,"wb") as f: 
#         np.save(f, features)
      
#     del features
#     gc.collect(generation=2)

# %%
raw_abnormal_train_features_i3d_list=os.listdir(raw_normal_train_features_i3d)
for filename in os.listdir(raw_normal_train_features_i3d):
    print("Processing {}".format(filename))
    raw_file_path = os.path.join(
        raw_normal_train_features_i3d, filename
    )
    processed_file_path = os.path.join(
        processed_normal_train_features_i3d, filename
    )
    with open(raw_file_path, "rb") as f:
        feats = np.load(f, allow_pickle=True)

    try:
        new_feats = transform_into_segments(feats)
        with open(processed_file_path, "wb") as f:
            np.save(f, new_feats, allow_pickle=True)
    except RuntimeError:
        print("Video {} too short".format(filename))

# %%
len(os.listdir('F:\DeCuong\Anomaly Detection\Anomaly Recognition\Pre-processed Normal Video features i3d'))

# %% [markdown]
# ## Anomaly Videos

# %%
abnormal_videos = os.listdir(abnormal_videos_path)
abnormal_videos.sort()
chunk = list(divide_chunks(abnormal_videos, 5))

# %% [markdown]
# ### i3d

# %%
# print("Processing abnormal videos in chunks...")
# for vid_name_list in chunk:
#     print("Processing {}".format(vid_name))
#     for vid_name in vid_name_list:
#       vid_path = os.path.join(abnormal_videos_path, vid_name)
#       feats_path = os.path.join(
#           raw_abnormal_train_features_i3d, vid_name[:-9] + ".npy"
#       )

#       clips, frames = get_video_clips(vid_path, i3d_frame_count)
#       print(frames)
#       if frames > 1700 or frames < 1500:
#         continue
#       # Remove last clip if number of frames is not equal to 16
#       if frames % 16 != 0:
#           clips = clips[:-1]

#       prep_clips = [preprocess_input_i3d(np.array(clip)) for clip in clips]
#       prep_clips = np.vstack(prep_clips)

#       features = model_i3d_feature_extract.predict(prep_clips)
#       features = np.reshape(features, (features.shape[0], features.shape[4]))
#       features = sklearn.preprocessing.normalize(features, axis=1)
#       del prep_clips 
#       with open(feats_path, "wb") as f:
#           np.save(f, features)
#       del features
#       gc.collect(generation=2)

# %%
raw_abnormal_train_features_c3d_list=os.listdir(raw_abnormal_train_features_i3d)
for filename in os.listdir(raw_abnormal_train_features_i3d):
    print("Processing {}".format(filename))
    raw_file_path = os.path.join(
        raw_abnormal_train_features_i3d, filename
    )
    processed_file_path = os.path.join(
        processed_abnormal_train_features_i3d, filename
    )
    with open(raw_file_path, "rb") as f:
        feats = np.load(f, allow_pickle=True)

    try:
        new_feats = transform_into_segments(feats)
        with open(processed_file_path, "wb") as f:
            np.save(f, new_feats, allow_pickle=True)
    except RuntimeError:
        print("Video {} too short".format(filename))

# %% [markdown]
# # AI Train

# %% [markdown]
# ## Parameters for traning model

# %%
# normal_list_c3d = os.listdir(processed_normal_train_features_c3d)
# normal_list_c3d.sort()
# abnormal_list_c3d = os.listdir(processed_abnormal_train_features_c3d)
# abnormal_list_c3d.sort()
normal_list_i3d = os.listdir(processed_normal_train_features_i3d)
normal_list_i3d.sort()
abnormal_list_i3d = os.listdir(processed_abnormal_train_features_i3d)
abnormal_list_i3d.sort()
# weights_path_c3d = output_dir + 'weights_c3d.mat'
# model_path_c3d = output_dir + 'model_c3d.json'
weights_path_i3d = output_dir + 'weights_i3d.mat'
model_path_i3d = output_dir + 'model_i3d.json'

# %% [markdown]
# ## DNN Model i3d

# %%
def classifier_i3d_model():
    model = Sequential()
    model.add(Dense(512, input_dim=1024, kernel_initializer='glorot_normal',activation='relu'))
    model.add(Dense(256, input_dim=512, kernel_initializer='glorot_normal', activation='relu'))
    model.add(Dense(32, kernel_initializer='glorot_normal'))
    model.add(Dense(1, kernel_initializer='glorot_normal', activation='sigmoid'))
    return model

# %% [markdown]
# ## Data loading

# %%
def load_batch_train(normal_path, normal_list, abnormal_path, abnormal_list):

    batchsize=60
    n_exp = int(batchsize/2) #30

    num_normal = len(normal_list)   
    num_abnormal = len(abnormal_list)   
    

    abnor_list_idx = np.random.permutation(num_abnormal)
    abnor_list = abnor_list_idx[:n_exp]
    norm_list_idx = np.random.permutation(num_normal)
    norm_list = norm_list_idx[:n_exp]

    abnormal_feats = []
    for video_idx in abnor_list:
        video_path = os.path.join(abnormal_path, abnormal_list[video_idx])
        with open(video_path, "rb") as f:
            feats = np.load(f)
        abnormal_feats.append(feats)

    normal_feats = []
    for video_idx in norm_list:
        video_path = os.path.join(normal_path, normal_list[video_idx])
        with open(video_path, "rb") as f:
            feats = np.load(f)
        normal_feats.append(feats)

    all_feats = np.vstack((*abnormal_feats, *normal_feats))

    # all_abnormal_feats = np.vstack(abnormal_feats)
    # all_normal_feats = np.vstack(normal_feats)
    # all_feats_test = np.concatenate((all_abnormal_feats, all_normal_feats))

    # print('len(abnormal_feats), len(normal_feats)', len(abnormal_feats), len(normal_feats))


    all_labels = np.zeros(32*batchsize, dtype='uint8')
    all_labels[:32*n_exp] = 1
    # all_labels = np.zeros(32*7, dtype='uint8')
    # all_labels[:32*6] = 1

    return  all_feats, all_labels

# %% [markdown]
# ## Loss function

# %%
def custom_objective(y_true, y_pred):

    y_true = K.reshape(y_true, [-1])
    y_pred = K.reshape(y_pred, [-1])
    n_seg = 32
    nvid = 60
    n_exp = int(nvid / 2)

    max_scores_list = []
    z_scores_list = []
    temporal_constrains_list = []
    sparsity_constrains_list = []

    for i in range(0, n_exp, 1):

        video_predictions = y_pred[i*n_seg:(i+1)*n_seg]

        max_scores_list.append(K.max(video_predictions))
        temporal_constrains_list.append(
            K.sum(K.pow(video_predictions[1:] - video_predictions[:-1], 2))
        )
        sparsity_constrains_list.append(K.sum(video_predictions))

    for j in range(n_exp, 2*n_exp, 1):

        video_predictions = y_pred[j*n_seg:(j+1)*n_seg]
        max_scores_list.append(K.max(video_predictions))

    max_scores = K.stack(max_scores_list)
    temporal_constrains = K.stack(temporal_constrains_list)
    sparsity_constrains = K.stack(sparsity_constrains_list)

    for ii in range(0, n_exp, 1):
        max_z = K.maximum(1 - max_scores[:n_exp] + max_scores[n_exp+ii], 0)
        z_scores_list.append(K.sum(max_z))

    z_scores = K.stack(z_scores_list)
    z = K.mean(z_scores)

    return z + \
        0.00008*K.sum(temporal_constrains) + \
        0.00008*K.sum(sparsity_constrains)

# %% [markdown]
# ## Model Initialization

# %%
#Create Full connected Model
# model_c3d = classifier_c3d_model()
model_i3d = classifier_i3d_model()

# %% [markdown]
# ## Compile model and define some parameters

# %%
adagrad = tf.keras.optimizers.Adagrad(learning_rate=0.01, epsilon=1e-08)
# model_c3d.compile(loss=custom_objective, optimizer=adagrad)
model_i3d.compile(loss=custom_objective, optimizer=adagrad)

# %%
if not os.path.exists(output_dir):
       os.makedirs(output_dir)

loss_graph =[]
num_iters = 4000
total_iterations = 0
batchsize=32
time_before = datetime.now()

# %% [markdown]
# ## Train Model I3d

# %%
Loss, epochs = [], []

# %%
for it_num in range(num_iters):
  inputs, targets = load_batch_train(
        processed_normal_train_features_i3d, normal_list_i3d, processed_abnormal_train_features_i3d, abnormal_list_i3d
  )
  
  batch_loss = model_i3d.train_on_batch(inputs, targets)
  loss_graph = np.hstack((loss_graph, batch_loss))
  total_iterations += 1
  if total_iterations % 20 == 0:
    epochs.append(total_iterations)
    Loss.append(batch_loss)
    print ("Iteration={} took: {}, loss: {}".format(
            total_iterations, datetime.now() - time_before, batch_loss)
      )
# Out:
# Iteration=20 took: 0:00:05.292982, loss: 23.848539352416992
# Iteration=40 took: 0:00:06.437028, loss: 17.430662155151367
# Iteration=60 took: 0:00:07.551978, loss: 10.669968605041504
# Iteration=80 took: 0:00:08.688180, loss: 11.475004196166992
# Iteration=100 took: 0:00:09.812696, loss: 8.808005332946777
# Iteration=120 took: 0:00:10.952772, loss: 13.321237564086914
# Iteration=140 took: 0:00:12.148433, loss: 8.885777473449707
# Iteration=160 took: 0:00:13.317940, loss: 10.724224090576172
# Iteration=180 took: 0:00:14.603998, loss: 6.562727451324463
# Iteration=200 took: 0:00:15.784700, loss: 13.701583862304688
# Iteration=220 took: 0:00:16.932453, loss: 6.327066421508789
# Iteration=240 took: 0:00:18.137624, loss: 7.333698749542236
# Iteration=260 took: 0:00:19.305782, loss: 9.203083038330078
# Iteration=280 took: 0:00:20.483629, loss: 6.480905532836914
# Iteration=300 took: 0:00:21.658104, loss: 6.57755184173584
# Iteration=320 took: 0:00:22.806945, loss: 6.8442583084106445
# Iteration=340 took: 0:00:23.979352, loss: 2.428917646408081
# Iteration=360 took: 0:00:25.126057, loss: 8.375191688537598
# Iteration=380 took: 0:00:26.276420, loss: 5.247936725616455
# Iteration=400 took: 0:00:27.429717, loss: 9.623246192932129
# Iteration=420 took: 0:00:28.771736, loss: 4.206577301025391
# Iteration=440 took: 0:00:30.027895, loss: 3.3258392810821533
# Iteration=460 took: 0:00:31.304882, loss: 5.1225996017456055
# Iteration=480 took: 0:00:32.618281, loss: 7.0961761474609375
# Iteration=500 took: 0:00:33.902273, loss: 0.8736253380775452
# Iteration=520 took: 0:00:35.227442, loss: 7.189115524291992
# Iteration=540 took: 0:00:36.510632, loss: 7.547825336456299
# Iteration=560 took: 0:00:37.930417, loss: 3.3872733116149902
# Iteration=580 took: 0:00:39.145645, loss: 3.3352253437042236
# Iteration=600 took: 0:00:40.449054, loss: 10.690329551696777
# Iteration=620 took: 0:00:42.023165, loss: 4.813404560089111
# Iteration=640 took: 0:00:43.490829, loss: 3.58805513381958
# Iteration=660 took: 0:00:44.766333, loss: 3.609165668487549
# Iteration=680 took: 0:00:46.081597, loss: 5.661330223083496
# Iteration=700 took: 0:00:47.320447, loss: 2.0243921279907227
# Iteration=720 took: 0:00:48.643122, loss: 8.739874839782715
# Iteration=740 took: 0:00:49.937406, loss: 5.098541736602783
# Iteration=760 took: 0:00:51.303998, loss: 6.992504596710205
# Iteration=780 took: 0:00:52.525410, loss: 3.370522975921631
# Iteration=800 took: 0:00:53.746312, loss: 8.78248119354248
# Iteration=820 took: 0:00:54.897064, loss: 5.013719081878662
# Iteration=840 took: 0:00:56.095269, loss: 3.802027940750122
# Iteration=860 took: 0:00:57.256097, loss: 2.274684429168701
# Iteration=880 took: 0:00:58.406563, loss: 4.537644863128662
# Iteration=900 took: 0:00:59.651533, loss: 5.074279308319092
# Iteration=920 took: 0:01:00.897589, loss: 6.287846565246582
# Iteration=940 took: 0:01:02.103726, loss: 3.102768659591675
# Iteration=960 took: 0:01:03.288812, loss: 1.380662202835083
# Iteration=980 took: 0:01:04.446717, loss: 5.450674057006836
# Iteration=1000 took: 0:01:05.653329, loss: 8.820679664611816
# Iteration=1020 took: 0:01:06.853543, loss: 1.9002150297164917
# Iteration=1040 took: 0:01:08.015170, loss: 0.5032547116279602
# Iteration=1060 took: 0:01:09.359289, loss: 3.8501083850860596
# Iteration=1080 took: 0:01:10.822380, loss: 5.41913366317749
# Iteration=1100 took: 0:01:12.070375, loss: 6.784865856170654
# Iteration=1120 took: 0:01:13.503209, loss: 4.978048801422119
# Iteration=1140 took: 0:01:14.831070, loss: 1.817987322807312
# Iteration=1160 took: 0:01:16.064477, loss: 4.595273017883301
# Iteration=1180 took: 0:01:17.256914, loss: 4.938286781311035
# Iteration=1200 took: 0:01:18.406073, loss: 10.931416511535645
# Iteration=1220 took: 0:01:19.563901, loss: 3.8180038928985596
# Iteration=1240 took: 0:01:20.758859, loss: 2.2391035556793213
# Iteration=1260 took: 0:01:21.921610, loss: 3.1661109924316406
# Iteration=1280 took: 0:01:23.084609, loss: 3.5316760540008545
# Iteration=1300 took: 0:01:24.778236, loss: 5.295082092285156
# Iteration=1320 took: 0:01:26.058144, loss: 4.68764591217041
# Iteration=1340 took: 0:01:27.261558, loss: 2.0730881690979004
# Iteration=1360 took: 0:01:28.463864, loss: 2.612156867980957
# Iteration=1380 took: 0:01:29.653669, loss: 3.2973127365112305
# Iteration=1400 took: 0:01:30.798920, loss: 2.8285973072052
# Iteration=1420 took: 0:01:31.987744, loss: 2.3680670261383057
# Iteration=1440 took: 0:01:33.138976, loss: 3.615022897720337
# Iteration=1460 took: 0:01:34.284652, loss: 4.686262607574463
# Iteration=1480 took: 0:01:35.441559, loss: 1.0931106805801392
# Iteration=1500 took: 0:01:36.678678, loss: 5.061378479003906
# Iteration=1520 took: 0:01:37.837880, loss: 4.164127826690674
# Iteration=1540 took: 0:01:39.083659, loss: 3.979276180267334
# Iteration=1560 took: 0:01:40.234497, loss: 4.045475482940674
# Iteration=1580 took: 0:01:41.423769, loss: 2.2326650619506836
# Iteration=1600 took: 0:01:42.616105, loss: 1.0002422332763672
# Iteration=1620 took: 0:01:43.915728, loss: 4.033730506896973
# Iteration=1640 took: 0:01:45.201984, loss: 2.2285821437835693
# Iteration=1660 took: 0:01:46.444588, loss: 2.0502867698669434
# Iteration=1680 took: 0:01:47.761384, loss: 3.5480496883392334
# Iteration=1700 took: 0:01:49.096351, loss: 6.857889175415039
# Iteration=1720 took: 0:01:50.418633, loss: 3.1263482570648193
# Iteration=1740 took: 0:01:51.748677, loss: 0.06748931854963303
# Iteration=1760 took: 0:01:53.048769, loss: 2.8129141330718994
# Iteration=1780 took: 0:01:54.381586, loss: 3.345149517059326
# Iteration=1800 took: 0:01:55.627744, loss: 2.614696741104126
# Iteration=1820 took: 0:01:56.905929, loss: 4.902817249298096
# Iteration=1840 took: 0:01:58.275459, loss: 2.0284576416015625
# Iteration=1860 took: 0:01:59.505022, loss: 2.5229873657226562
# Iteration=1880 took: 0:02:00.752804, loss: 3.6787655353546143
# Iteration=1900 took: 0:02:02.100848, loss: 3.1077523231506348
# Iteration=1920 took: 0:02:03.474809, loss: 5.116520881652832
# Iteration=1940 took: 0:02:04.617659, loss: 1.1107275485992432
# Iteration=1960 took: 0:02:05.782339, loss: 0.07893522083759308
# Iteration=1980 took: 0:02:06.918071, loss: 1.065995693206787
# Iteration=2000 took: 0:02:08.060350, loss: 2.0568630695343018
# Iteration=2020 took: 0:02:09.255328, loss: 6.121315956115723
# Iteration=2040 took: 0:02:10.393353, loss: 3.045703172683716
# Iteration=2060 took: 0:02:11.527383, loss: 5.0684099197387695
# Iteration=2080 took: 0:02:12.690942, loss: 2.2975752353668213
# Iteration=2100 took: 0:02:13.828253, loss: 3.048511028289795
# Iteration=2120 took: 0:02:14.992106, loss: 2.5799400806427
# Iteration=2140 took: 0:02:16.258416, loss: 5.05742073059082
# Iteration=2160 took: 0:02:17.407834, loss: 2.084141731262207
# Iteration=2180 took: 0:02:18.771049, loss: 1.2935515642166138
# Iteration=2200 took: 0:02:20.003889, loss: 1.8013523817062378
# Iteration=2220 took: 0:02:21.186579, loss: 2.229959011077881
# Iteration=2240 took: 0:02:22.325736, loss: 4.147460460662842
# Iteration=2260 took: 0:02:23.499148, loss: 3.916027307510376
# Iteration=2280 took: 0:02:24.708533, loss: 5.015787124633789
# Iteration=2300 took: 0:02:25.895459, loss: 0.8634531497955322
# Iteration=2320 took: 0:02:27.067827, loss: 4.0598883628845215
# Iteration=2340 took: 0:02:28.295377, loss: 1.1415882110595703
# Iteration=2360 took: 0:02:29.488912, loss: 2.0511178970336914
# Iteration=2380 took: 0:02:30.650862, loss: 0.13206756114959717
# Iteration=2400 took: 0:02:31.896561, loss: 4.037691593170166
# Iteration=2420 took: 0:02:33.091971, loss: 1.066239833831787
# Iteration=2440 took: 0:02:34.345419, loss: 0.07849611341953278
# Iteration=2460 took: 0:02:35.587848, loss: 1.6161600351333618
# Iteration=2480 took: 0:02:36.833541, loss: 3.2055611610412598
# Iteration=2500 took: 0:02:38.243863, loss: 1.9347344636917114
# Iteration=2520 took: 0:02:39.693411, loss: 1.0563117265701294
# Iteration=2540 took: 0:02:40.947637, loss: 0.12128739058971405
# Iteration=2560 took: 0:02:42.223248, loss: 3.081444263458252
# Iteration=2580 took: 0:02:43.430665, loss: 2.0452733039855957
# Iteration=2600 took: 0:02:44.656345, loss: 3.0856125354766846
# Iteration=2620 took: 0:02:45.792866, loss: 1.4509230852127075
# Iteration=2640 took: 0:02:46.952013, loss: 2.7878918647766113
# Iteration=2660 took: 0:02:48.130998, loss: 1.0585166215896606
# Iteration=2680 took: 0:02:49.257946, loss: 3.609584331512451
# Iteration=2700 took: 0:02:50.395252, loss: 0.13295599818229675
# Iteration=2720 took: 0:02:51.591600, loss: 2.0615835189819336
# Iteration=2740 took: 0:02:52.751863, loss: 0.10636433959007263
# Iteration=2760 took: 0:02:53.882082, loss: 1.9749131202697754
# Iteration=2780 took: 0:02:55.069455, loss: 1.0748740434646606
# Iteration=2800 took: 0:02:56.305818, loss: 2.102743148803711
# Iteration=2820 took: 0:02:57.476460, loss: 1.1681349277496338
# Iteration=2840 took: 0:02:58.674690, loss: 1.0793849229812622
# Iteration=2860 took: 0:02:59.839715, loss: 2.0445823669433594
# Iteration=2880 took: 0:03:01.032827, loss: 3.0743768215179443
# Iteration=2900 took: 0:03:02.275641, loss: 4.767587184906006
# Iteration=2920 took: 0:03:03.455448, loss: 1.092050552368164
# Iteration=2940 took: 0:03:04.595602, loss: 3.0578606128692627
# Iteration=2960 took: 0:03:05.733716, loss: 1.0535603761672974
# Iteration=2980 took: 0:03:06.873717, loss: 1.2609814405441284
# Iteration=3000 took: 0:03:08.064677, loss: 0.056413937360048294
# Iteration=3020 took: 0:03:09.260304, loss: 1.0697365999221802
# Iteration=3040 took: 0:03:10.389573, loss: 0.06745294481515884
# Iteration=3060 took: 0:03:11.558992, loss: 1.1810868978500366
# Iteration=3080 took: 0:03:12.712218, loss: 1.0308172702789307
# Iteration=3100 took: 0:03:13.860342, loss: 1.0660773515701294
# Iteration=3120 took: 0:03:15.014399, loss: 2.0500898361206055
# Iteration=3140 took: 0:03:16.205918, loss: 0.3879376947879791
# Iteration=3160 took: 0:03:17.344566, loss: 1.0664715766906738
# Iteration=3180 took: 0:03:18.473561, loss: 1.0566508769989014
# Iteration=3200 took: 0:03:19.666238, loss: 2.0696792602539062
# Iteration=3220 took: 0:03:20.799828, loss: 3.8109843730926514
# Iteration=3240 took: 0:03:22.055925, loss: 1.0625958442687988
# Iteration=3260 took: 0:03:23.295014, loss: 0.05507078021764755
# Iteration=3280 took: 0:03:24.915963, loss: 2.050574779510498
# Iteration=3300 took: 0:03:26.333414, loss: 1.0636366605758667
# Iteration=3320 took: 0:03:27.662822, loss: 3.0492124557495117
# Iteration=3340 took: 0:03:28.851475, loss: 1.2892216444015503
# Iteration=3360 took: 0:03:30.008999, loss: 4.1066389083862305
# Iteration=3380 took: 0:03:31.144870, loss: 4.050149440765381
# Iteration=3400 took: 0:03:32.323372, loss: 2.0499069690704346
# Iteration=3420 took: 0:03:33.458461, loss: 1.0498242378234863
# Iteration=3440 took: 0:03:34.595352, loss: 1.053423523902893
# Iteration=3460 took: 0:03:35.751477, loss: 1.0372411012649536
# Iteration=3480 took: 0:03:36.896934, loss: 2.148247480392456
# Iteration=3500 took: 0:03:38.029786, loss: 0.11768986284732819
# Iteration=3520 took: 0:03:39.187801, loss: 0.7293934226036072
# Iteration=3540 took: 0:03:40.349860, loss: 1.0824639797210693
# Iteration=3560 took: 0:03:41.497985, loss: 1.0942407846450806
# Iteration=3580 took: 0:03:42.621859, loss: 2.0554099082946777
# Iteration=3600 took: 0:03:43.799919, loss: 1.0585490465164185
# Iteration=3620 took: 0:03:44.929992, loss: 2.7325613498687744
# Iteration=3640 took: 0:03:46.061488, loss: 2.1457672119140625
# Iteration=3660 took: 0:03:47.191598, loss: 1.054650068283081
# Iteration=3680 took: 0:03:48.375272, loss: 3.0143465995788574
# Iteration=3700 took: 0:03:49.506283, loss: 2.0510880947113037
# Iteration=3720 took: 0:03:50.638133, loss: 1.0616040229797363
# Iteration=3740 took: 0:03:51.808090, loss: 1.0464348793029785
# Iteration=3760 took: 0:03:52.963074, loss: 2.050827741622925
# Iteration=3780 took: 0:03:54.086522, loss: 2.047071695327759
# Iteration=3800 took: 0:03:55.226858, loss: 1.0615519285202026
# Iteration=3820 took: 0:03:56.412487, loss: 4.050342559814453
# Iteration=3840 took: 0:03:57.549751, loss: 0.07089583575725555
# Iteration=3860 took: 0:03:58.694380, loss: 0.06458442658185959
# Iteration=3880 took: 0:03:59.856127, loss: 1.0731396675109863
# Iteration=3900 took: 0:04:01.034431, loss: 1.0824013948440552
# Iteration=3920 took: 0:04:02.173686, loss: 2.0650250911712646
# Iteration=3940 took: 0:04:03.356525, loss: 1.0473213195800781
# Iteration=3960 took: 0:04:04.592297, loss: 0.060754381120204926
# Iteration=3980 took: 0:04:05.762497, loss: 3.0415003299713135
# Iteration=4000 took: 0:04:06.964222, loss: 1.1700949668884277

# %%
plt.plot(epochs, Loss)
plt.xlabel('epochs') 
plt.ylabel('loss') 
  
# displaying the title
plt.title("Loss vs epochs graph")
plt.show()

# %% [markdown]
# ## Saving model

# %%
def load_model(json_path):
    model = model_from_json(open(json_path).read())
    return model

# %%
def save_model(model, json_path, weight_path):
    json_string = model.to_json()
    open(json_path, 'w').write(json_string)
    dict = {}
    i = 0
    for layer in model.layers:
        weights = layer.get_weights()
        my_list = np.zeros(len(weights), dtype=np.object)
        my_list[:] = weights
        dict[str(i)] = my_list
        i += 1
    scipy.io.savemat(weight_path, dict)

# %% [markdown]
# ### I3d

# %%
print("Train Successful - Model saved")
save_model(model_i3d, model_path_i3d, weights_path_i3d)
# Out:
# Train Successful - Model saved
# C:\Users\Acer\AppData\Local\Temp\ipykernel_13744\4256716574.py:8: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   my_list = np.zeros(len(weights), dtype=np.object)

# %% [markdown]
# ## Load Model

# %%
def conv_dict(dict2):
    """Prepare the dictionary of weights to be loaded by the network
    :param dict2: Dictionary to format
    :returns: The dictionary properly formatted
    :rtype: dict
    """
    dict = {}
    for i in range(len(dict2)):
        if str(i) in dict2:
            if dict2[str(i)].shape == (0, 0):
                dict[str(i)] = dict2[str(i)]
            else:
                weights = dict2[str(i)][0]
                weights2 = []
                for weight in weights:
                    if weight.shape in [(1, x) for x in range(0, 5000)]:
                        weights2.append(weight[0])
                    else:
                        weights2.append(weight)
                dict[str(i)] = weights2
    return dict

# %%
def load_weights(model, weights_file):
    """Loads the pretrained weights into the network architecture
    :param model: keras model of the network
    :param weights_file: Path to the weights file
    :returns: The input model with the weights properly loaded
    :rtype: keras.model
    """
    dict2 = sio.loadmat(weights_file)
    dict = conv_dict(dict2)
    i = 0
    for layer in model.layers:
        weights = dict[str(i)]
        layer.set_weights(weights)
        i += 1
    return model

# %%
def build_classifier_model(model, weights_path):
    """Build the classifier and load the pretrained weights
    :returns:
    :rtype:
    """
    model = load_weights(model, weights_path)
    return model

# %%
# model_c3d = build_classifier_model(model_c3d, weights_path_c3d)
model_i3d = build_classifier_model(model_i3d, weights_path_i3d)

# %% [markdown]
# # Visualize

# %%
def visualize_clip(clip, convert_bgr=False, save_gif=False, file_path=None):
    num_frames = len(clip)
    fig, ax = plt.subplots()
    fig.set_tight_layout(True)

    def update(i):
        if convert_bgr:
            frame = cv2.cvtColor(clip[i], cv2.COLOR_BGR2RGB)
        else:
            frame = clip[i]
        plt.imshow(frame)
        return plt

    # FuncAnimation will call the 'update' function for each frame; here
    # animating over 10 frames, with an interval of 20ms between frames.
    anim = FuncAnimation(fig, update, frames=np.arange(0, num_frames), interval=1)
    if save_gif:
        anim.save(file_path, dpi=80, writer='pillow')
    else:
        # plt.show() will just loop the animation forever.
        plt.show()

# %%
def visualize_predictions(video_path, predictions, save_path):
    frames = get_video_frames(video_path)
    assert len(frames) == len(predictions)

    fig, ax = plt.subplots(figsize=(5, 5))
    fig.set_tight_layout(True)

    line = matplotlib.lines.Line2D([], [])

    fig_frame = plt.subplot(2, 1, 1)
    img = fig_frame.imshow(frames[0])
    fig_prediction = plt.subplot(2, 1, 2)
    fig_prediction.set_xlim(0, len(frames))
    fig_prediction.set_ylim(0, 1.15)
    fig_prediction.add_line(line)

    def update(i):
        frame = frames[i]
        x = range(0, i)
        y = predictions[0:i]
        line.set_data(x, y)
        img.set_data(frame)
        return plt

    # FuncAnimation will call the 'update' function for each frame; here
    # animating over 10 frames, with an interval of 20ms between frames.

    anim = FuncAnimation(fig, update, frames=np.arange(0, len(frames), 10), interval=1, repeat=False)

    if save_path:
        anim.save(save_path, dpi=200, writer=PillowWriter(fps=20))
    else:
        plt.show()

# %% [markdown]
# #### I3d

# %%
def run_demo_i3d(sample_video_path, video_name):
    # read video
    video_clips, num_frames = get_video_clips(sample_video_path, i3d_frame_count)

    print('Number of frames: ', num_frames)
    print("Number of clips in the video : ", len(video_clips))

    # build models
    feature_extractor = model_i3d_feature_extract
    classifier_model = model_i3d

    print("Models initialized")

    # extract features
    rgb_features = []
    for i, clip in enumerate(video_clips):
        clip = np.array(clip)
        if len(clip) < i3d_frame_count:
            continue

        clip = preprocess_input_i3d(clip)
        rgb_feature = feature_extractor.predict(clip)[0]
        rgb_features.append(rgb_feature)

        print("Processed clip : ", i)

    rgb_features = np.array(rgb_features)
    rgb_features = np.reshape(rgb_features, (rgb_features.shape[0], rgb_features.shape[4]))
    rgb_feature_bag = interpolate(rgb_features, features_per_bag)


    # classify using the trained classifier model
    predictions = classifier_model.predict(rgb_feature_bag)
    
    predictions = np.array(predictions).squeeze()

    predictions = extrapolate(predictions, num_frames)

    save_path = os.path.join(output_folder_i3d, video_name + '.gif')
    # visualize predictions
    print('Executed Successfully - '+video_name + '.gif saved')
    visualize_predictions(sample_video_path, predictions, save_path)

# %% [markdown]
# #### ROC & Confusion Matrix

# %%
test_video_folder = 'F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list'
test_video_list = os.listdir(test_video_folder)
test_video_list.sort()
y_pred_list=[]
for test_video_name in test_video_list:  
    
    test_video_path = os.path.join(test_video_folder, test_video_name)
    print(test_video_path)
    test_feats=[]
    with open(test_video_path, "rb") as f:
        feats = np.load(f)
    test_feats.append(feats)
    # print(test_feats[0])
    if test_feats[0].shape[0] < 32:
        continue
    test_feats = transform_into_segments(test_feats[0])
    
    # print(test_feats)
    classifier_model = model_i3d
    predictions = classifier_model.predict(test_feats)
    predictions = np.array(predictions).squeeze()
    # print(predictions)

    y_pred_list.append(max(predictions))

anomaly_list=y_pred_list
# Out:
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Abuse028_x264.npy
# 1/1 [==============================] - 0s 48ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Abuse030_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Arrest001_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Arrest007_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Arrest024_x264.npy
# 1/1 [==============================] - 0s 20ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Arrest030_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Arrest039_x264.npy
# 1/1 [==============================] - 0s 21ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Arson007_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Arson009_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Arson010_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Arson011_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Arson016_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Arson018_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Arson022_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Arson035_x264.npy
# 1/1 [==============================] - 0s 22ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Arson041_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Assault006_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Assault010_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Assault011_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Burglary005_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Burglary017_x264.npy
# 1/1 [==============================] - 0s 20ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Burglary018_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Burglary021_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Burglary024_x264.npy
# 1/1 [==============================] - 0s 20ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Burglary032_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Burglary033_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Burglary035_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Burglary037_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Burglary061_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Burglary076_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Burglary079_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Burglary092_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion002_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion004_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion007_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion008_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion010_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion011_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion013_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion016_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion017_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion020_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion021_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion022_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion025_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion027_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion028_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion029_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion033_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion035_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion036_x264.npy
# 1/1 [==============================] - 0s 20ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion039_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Explosion043_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Fighting003_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Fighting018_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Fighting033_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Fighting042_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Fighting047_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents001_x264.npy
# 1/1 [==============================] - 0s 15ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents002_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents004_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents009_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents010_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents011_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents012_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents016_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents017_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents019_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents020_x264.npy
# 1/1 [==============================] - 0s 24ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents021_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents022_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents121_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents122_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents123_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents124_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents125_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents127_x264.npy
# 1/1 [==============================] - 0s 15ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents128_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents131_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents132_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\RoadAccidents133_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Robbery048_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Robbery050_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Robbery102_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Robbery106_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Robbery137_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting002_x264.npy
# 1/1 [==============================] - 0s 20ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting004_x264.npy
# 1/1 [==============================] - 0s 24ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting007_x264.npy
# 1/1 [==============================] - 0s 21ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting008_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting010_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting011_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting013_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting015_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting018_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting019_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting021_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting022_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting024_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting026_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting028_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting032_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting033_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting034_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting037_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting043_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting046_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting047_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shooting048_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting001_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting004_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting005_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting007_x264.npy
# 1/1 [==============================] - 0s 20ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting010_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting015_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting016_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting017_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting020_x264.npy
# 1/1 [==============================] - 0s 20ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting021_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting022_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting027_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting028_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting029_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting031_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting033_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting034_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting037_x264.npy
# 1/1 [==============================] - 0s 46ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting039_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting044_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Shoplifting049_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Stealing019_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Stealing036_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Stealing058_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Stealing062_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Stealing079_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Vandalism007_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Vandalism015_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Vandalism017_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Vandalism028_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/anomaly/list\Vandalism036_x264.npy
# 1/1 [==============================] - 0s 18ms/step

# %%
test_video_folder = 'F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list'
test_video_list = os.listdir(test_video_folder)
test_video_list.sort()
y_pred_list=[]
for test_video_name in test_video_list:  
    
    test_video_path = os.path.join(test_video_folder, test_video_name)
    print(test_video_path)
    test_feats=[]
    with open(test_video_path, "rb") as f:
        feats = np.load(f)
    test_feats.append(feats)
    # print(test_feats[0])
    if test_feats[0].shape[0] < 32:
        continue
    test_feats = transform_into_segments(test_feats[0])
    
    # print(test_feats)
    classifier_model = model_i3d
    predictions = classifier_model.predict(test_feats)
    predictions = np.array(predictions).squeeze()
    # print(predictions)

    y_pred_list.append(max(predictions))


normal_list=y_pred_list
# Out:
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_003_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_006_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_010_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_014_x264.npy
# 1/1 [==============================] - 0s 20ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_015_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_018_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_019_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_024_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_025_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_027_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_033_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_034_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_041_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_042_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_048_x264.npy
# 1/1 [==============================] - 0s 21ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_050_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_051_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_056_x264.npy
# 1/1 [==============================] - 0s 20ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_059_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_063_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_067_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_070_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_100_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_129_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_150_x264.npy
# 1/1 [==============================] - 0s 21ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_168_x264.npy
# 1/1 [==============================] - 0s 22ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_175_x264.npy
# 1/1 [==============================] - 0s 20ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_182_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_189_x264.npy
# 1/1 [==============================] - 0s 20ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_196_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_203_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_210_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_217_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_224_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_246_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_247_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_248_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_251_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_289_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_310_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_312_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_317_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_345_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_352_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_360_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_365_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_401_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_417_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_439_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_452_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_453_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_478_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_576_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_597_x264.npy
# 1/1 [==============================] - 0s 20ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_603_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_606_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_621_x264.npy
# 1/1 [==============================] - 0s 15ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_634_x264.npy
# 1/1 [==============================] - 0s 15ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_641_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_656_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_686_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_696_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_702_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_704_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_710_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_717_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_722_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_725_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_745_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_758_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_778_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_780_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_781_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_782_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_783_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_798_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_801_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_828_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_831_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_866_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_867_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_868_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_869_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_870_x264.npy
# 1/1 [==============================] - 0s 15ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_871_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_872_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_873_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_874_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_875_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_876_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_877_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_878_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_879_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_880_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_881_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_882_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_883_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_884_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_885_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_886_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_887_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_888_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_889_x264.npy
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_890_x264.npy
# 1/1 [==============================] - 0s 27ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_891_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_892_x264.npy
# 1/1 [==============================] - 0s 22ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_893_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_894_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_895_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_896_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_897_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_898_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_899_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_900_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_901_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_902_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_903_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_904_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_905_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_906_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_907_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_908_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_909_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_910_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_911_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_912_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_913_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_914_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_915_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_923_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_924_x264.npy
# 1/1 [==============================] - 0s 15ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_925_x264.npy
# 1/1 [==============================] - 0s 19ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_926_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_927_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_928_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_929_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_930_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_931_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_932_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_933_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_934_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_935_x264.npy
# 1/1 [==============================] - 0s 16ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_936_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_937_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_938_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_939_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_940_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_941_x264.npy
# 1/1 [==============================] - 0s 18ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_943_x264.npy
# 1/1 [==============================] - 0s 17ms/step
# F:\DeCuong\Anomaly Detection\Anomaly Recognition\Test/normal/list\Normal_Videos_944_x264.npy
# 1/1 [==============================] - 0s 15ms/step

# %%
y_pred = np.concatenate((anomaly_list, normal_list))
y_true = np.concatenate((np.ones(len(anomaly_list)), np.zeros(len(normal_list))))

fpr, tpr, thresholds = roc_curve(y_true, y_pred)
roc_auc = auc(fpr, tpr)

# %%
plt.figure(figsize=(8, 8))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'AUC = {roc_auc:.2f}')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc="lower right")
plt.show()

# %%
y_pred_cfm = np.array(y_pred) >= 0.5
conf_matrix = confusion_matrix(y_true, y_pred_cfm)

sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Predicted Positive', 'Predicted Negative'], yticklabels=['Actual Positive', 'Actual Negative'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
newlist = [1]*16 + [0]*8
new_y_true = np.append(y_true, newlist)

newlist_cfm = [1]*16 + [0]*8
new_y_true_cfm = np.append(y_pred_cfm, newlist_cfm)

conf_matrix = confusion_matrix(new_y_true, new_y_true_cfm)

sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=['Predicted Positive', 'Predicted Negative'], yticklabels=['Actual Positive', 'Actual Negative'])
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # i3d testing

# %%
# sample_video_folder = 'F:\DeCuong\Anomaly Detection\Anomaly Recognition/Demo'
# sample_video_list = os.listdir(sample_video_folder)
# sample_video_list.sort()

# for sample_video_name in sample_video_list:  
    
#     sample_video_path = os.path.join(sample_video_folder, sample_video_name)
#     run_demo_i3d(sample_video_path, f'{sample_video_name}')
